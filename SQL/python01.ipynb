# %%
import pymysql

db = pymysql.connect(
    host= "localhost",
    port= 3306,
    user= "root",
    passwd= "hithere4961",
    db = "ecommerce_v1",
    charset = "utf8"
)

# %%
db

# %%
ecommercev1 = db.cursor()

# %%
ecommercev1

# %%
sql = """
    CREATE TABLE product(
        product_CODE
