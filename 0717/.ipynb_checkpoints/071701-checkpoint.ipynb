# %%
import requests

#url = "https://apis.data.go.kr/B551011/GoCamping/basedList?numOfRows=100&pageNo=1&MobileOS=ETC&MobileApp=camping&serviceKey=EUkNxC%2BT3jASuqEPBhHgFvYbHdwvvFB5RcniMhZReUDKfgglS7ulOa7oxOzjFDlr5MwDivJX%2FaqrjD881%2BdY1w%3D%3D&_type=json"
url = "https://apis.data.go.kr/B551011/GoCamping/basedList"
requests_params = {
    'numOfRows':'50',
    'pageNo' : '1',
    'MobileOS' : 'ETC',
    'MobileApp' : 'camping',
    'serviceKey' : 'UkNxC%2BT3jASuqEPBhHgFvYbHdwvvFB5RcniMhZReUDKfgglS7ulOa7oxOzjFDlr5MwDivJX%2FaqrjD881%2BdY1w%3D%3D',
    '_type' : 'xml' 
}

res = requests.get(url, params = requests_params)
# Out:
# ---------------------------------------------------------------------------
# SSLError                                  Traceback (most recent call last)
# File ~\AppData\Roaming\Python\Python313\site-packages\urllib3\connectionpool.py:464, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     463 try:
# --> 464     self._validate_conn(conn)
#     465 except (SocketTimeout, BaseSSLError) as e:
#
# File ~\AppData\Roaming\Python\Python313\site-packages\urllib3\connectionpool.py:1093, in HTTPSConnectionPool._validate_conn(self, conn)
#    1092 if conn.is_closed:
# -> 1093     conn.connect()
#    1095 # TODO revise this, see https://github.com/urllib3/urllib3/issues/2791
#
# File ~\AppData\Roaming\Python\Python313\site-packages\urllib3\connection.py:790, in HTTPSConnection.connect(self)
#     788 server_hostname_rm_dot = server_hostname.rstrip(".")
# ...

# %%
import subprocess #curl 처럼 파이썬 외부에 사용할 수 있는 명령어를 실행할 수 있게 해줌 

url = "https://apis.data.go.kr/B551011/GoCamping/basedList?numOfRows=100&pageNo=1&MobileOS=ETC&MobileApp=camping&serviceKey=EUkNxC%2BT3jASuqEPBhHgFvYbHdwvvFB5RcniMhZReUDKfgglS7ulOa7oxOzjFDlr5MwDivJX%2FaqrjD881%2BdY1w%3D%3D&_type=xml"
result = subprocess.run(["curl", "-k", url], capture_output = True,encoding="UTF-8" , text=True )
print(result.stdout)
# Out:
# <?xml version="1.0" encoding="UTF-8" standalone="yes"?><response><header>
#   <resultCode>0000</resultCode>
#   <resultMsg>OK</resultMsg>
# </header><body><items>
#   <item>
#     <contentId>401</contentId>
#     <facltNm>국립황정산자연휴양림</facltNm>
#     <lineIntro>아름다운 자연경관과 맑은 계곡물이 조화를 이룬 캠핑장</lineIntro>
#     <intro>국립황정산 자연휴양림 캠핑장은 충북 단양군 대강면에 자리 잡고 있다. 단양군청을 기점으로 약 22km 거리에 있으며, 자동차를 타고 단양로, 사인암로, 황정산로를 차례로 달리면 도착한다. 이동시간은 40분정도 걸린다. 이곳은 국립황정산 자연휴양림에 조성했고 덕분에 아름다운 자연경관에서 캠핑을 즐길 수 있다. 캠핑장에는 데크로 이뤄진 일반 야영장 23면을 마련했다. 사이트 크기는 가로 3.6m 세로 3.6m이며, 간격이 넓고 여유롭다. 개인 트레일러와 카라반 입장이 가능하고 화로대, 전기를 이용할 수 있다. 단 산불조심 기간에는 화로대를 사용할 수 없다. 캠핑장은 봄, 여름, 가을 운영하며, 예약은 온라인 예약대기로만 받는다. 아울러 반려견은 크기에 상관없이 동반 입장이 불가능하다.  캠핑장 주변에는 미륵대흥사, 단양 방곡도깨비마을 등 관광지가 즐비하다. 오리요리를 맛볼 수 있는 음식점 수리수리봉봉도 있다. </intro>
#     <allar>20000</allar>
#     <insrncAt>Y</insrncAt>
#     <trsagntNo>2022-1</trsagntNo>
#     <bizrno>305-83-04961</bizrno>
#     <facltDivNm>국립공원</facltDivNm>
#     <mangeDivNm>직영</mangeDivNm>
# ...

# %%
import subprocess #curl 처럼 파이썬 외부에 사용할 수 있는 명령어를 실행할 수 있게 해줌 
import xml.etree.ElementTree as ET 
import requests
import openpyxl
from openpyxl.drawing.image import Image as exim
from io import BytesIO

url = "https://apis.data.go.kr/B551011/GoCamping/basedList?numOfRows=50&pageNo=1&MobileOS=ETC&MobileApp=camping&serviceKey=EUkNxC%2BT3jASuqEPBhHgFvYbHdwvvFB5RcniMhZReUDKfgglS7ulOa7oxOzjFDlr5MwDivJX%2FaqrjD881%2BdY1w%3D%3D&_type=xml"

result = subprocess.run(["curl", "-k", url], capture_output = True,encoding="UTF-8" , text=True )
root = ET.fromstring(result.stdout)

wb = openpyxl.Workbook()
ws= wb.active
ws.title="캠핑장정보"
ws.append(["아이디", "이름", "이미지", "캠핑장 지역", "주소" , "홈페이지"])


items = root.findall(".//item")
row = 2 

for item in items :
    contentId = item.findtext("contentId", default="")
    facltNm = item.findtext("facltNm", default="")
    firstImageUrl = item.findtext("firstImageUrl", default="")
    doNm = item.findtext("doNm", default="")
    addr1 = item.findtext("addr1", default="")
    homepage = item.findtext("homepage", default="")
    ws.append([contentId,facltNm,"",doNm,addr1,homepage])

    if firstImageUrl :
        try:
            img_data = requests.get(firstImageUrl,timeout=10).content
            img_file = BytesIO(img_data)
            img = exim(img_file)
            img.width = 100
            img.height = 75 
            ws.add_image(img, f"C{row}")
            ws.row_dimensions[row].height=50
        except Exception as e : 
            print(f"[경고] 이미지 다운로드 실패 : {firstImageUrl} -> {e}")
    row += 1 

ws.column_dimensions["B"].width = 30
ws.column_dimensions["C"].width = 20
ws.column_dimensions["D"].width = 15
ws.column_dimensions["E"].width = 50
ws.column_dimensions["F"].width = 50
wb.save("camping_info_4.xlsx")
print("✅")
# Out:
# ✅

# %%
import subprocess #curl 처럼 파이썬 외부에 사용할 수 있는 명령어를 실행할 수 있게 해줌 
import xml.etree.ElementTree as ET 
import openpyxl

url = "https://apis.data.go.kr/B551011/GoCamping/basedList?numOfRows=50&pageNo=1&MobileOS=ETC&MobileApp=camping&serviceKey=EUkNxC%2BT3jASuqEPBhHgFvYbHdwvvFB5RcniMhZReUDKfgglS7ulOa7oxOzjFDlr5MwDivJX%2FaqrjD881%2BdY1w%3D%3D&_type=xml"

result = subprocess.run(["curl", "-k", url], capture_output = True,encoding="UTF-8" , text=True )
root = ET.fromstring(result.stdout)

# wb = openpyxl.Workbook()
# ws= wb.active
# ws.title="캠핑장정보"
# ws.append(["아이디", "이름", "이미지", "캠핑장 지역", "주소" , "홈페이지"])


items = root.findall(".//item")
camplist = []
for item in items :
    contentId = item.findtext("contentId", default="")
    facltNm = item.findtext("facltNm", default="")
    firstImageUrl = item.findtext("firstImageUrl", default="")
    doNm = item.findtext("doNm", default="")
    addr1 = item.findtext("addr1", default="")
    homepage = item.findtext("homepage", default="")
   
    camptuple = (contentId,facltNm,firstImageUrl,doNm,addr1,homepage)
    camplist.extend(camptuple)
