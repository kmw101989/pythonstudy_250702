# %% [markdown]
# #### 정규표현식 문법 리스트
# - [0-9] :숫자를 찾음 => \d
# - [^0-9] :숫자가 아닌 형태의 값을 찾음 => \D
# - [\t\n\r\f\v] : 탭, 줄바꿈 등의 문자를 찾고자 할 때 => \s
# - [^\t\n\r\f\v] : 탭 , 여백 , 줄바꿈 을 제외한 값을 찾고자 할 때 => \S
# - [A-Z] : 대문자 알파벳을 찾음
# - [a-z] : 소문자를 찾음
# - [A-Za-z0-9] : 문자 혹은 숫자 값을 찾음 \w
# - [^A-Za-z0-9] : 문자 혹은 숫자 외의 값을 찾음 => \W

# %% [markdown]
# #### 정규표현식 문법 리스트 -2
# - " . " : 문자 한개
# - " ? ": 앞에 있는 문자가 0번 또는 1번 표시되는 패턴 = 없어도 되고 있다면 한 번만 있어야 하는 패턴
# - " + ": 앞에 있는 문자가 1번 또는 그 이상 반복되는 패턴
# - " * ": 앞에 있는 문자가 0번 또는 그 이상 반복되는 패턴

# %% [markdown]
# #### 정규표현식 문법 리스트 -3
# - {n} : 앞에 있는 문자가 n번 반복되는 패턴
# - {m,n} : 앞에 있는 문자가 m번 반복되는 패턴부터n번 반복되는 패턴까지
# - [] : 대괄호 내부에 입력한 값을 "또는"의 형태로 찾아올 수 있는 패턴
# - ex) [abc] => [abcdefg]
# - "-" : 패턴 내 모든 문자를 일일히 다 기입할 수 없기 때문에
# - 한글은 [가-힣]

# %% [markdown]
# #### 정규표현식 문법 리스트 -4
# - match : 문자열의 처음부터 끝까지 정규표현식과 매칭되는 문자만을 찾아서 리턴
# - search : 문자열 전체 중에서 정규표현식과 매칭되어지는 문자가 있으면 리턴
# - findall : 패턴과 매칭되는 모든 문자열을 리스트 형태로 리턴
# - split :

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup as bs 
import re

url = "https://crawlingtest.netlify.app/"
res = urlopen(url)
soup = bs(res,"html.parser")
data = soup.select("ul#dev_course_list > li.course")

for item in data : 
    print(re.sub("[\[0-9]+\]","", item.get_text()).strip()) # 어떤걸, 어떤걸로, 어디서 
    # print(item.get_text().strip())
# Out:
# (초급) - 강사가 실제 사용하는 자동 프로그램 소개
# (초급) - 필요한 프로그램 설치 시연
# (초급) - 데이터를 엑셀 파일로 만들기
# (초급) -     엑셀 파일 이쁘게! 이쁘게!
# (초급) -     나대신 주기적으로 파이썬 프로그램
#           실행하기
# (초급) - 파이썬으로 슬랙(slack) 메신저에 글쓰기
# (초급) - 웹사이트 변경사항 주기적으로 체크해서, 메신저로 알람주기
# (초급) - 네이버 API 사용해서, 블로그에 글쓰기
# (중급) - 자동으로 쿠팡파트너스 API 로 가져온 상품 정보, 네이버
#           블로그/트위터에 홍보하기

# %%
import openpyxl
import re

regex = re.compile("[A-Za-z]+\.")

wb = openpyxl.load_workbook("train.xlsx")
ws = wb.active 

for each_row in ws.rows:
    print(each_row[3].value)
    print(regex.findall(each_row[3].value))
# Out:
# Name
# []
# Braund, Mr. Owen Harris
# ['Mr.']
# Cumings, Mrs. John Bradley (Florence Briggs Thayer)
# ['Mrs.']
# Heikkinen, Miss. Laina
# ['Miss.']
# Futrelle, Mrs. Jacques Heath (Lily May Peel)
# ['Mrs.']
# Allen, Mr. William Henry
# ['Mr.']
# Moran, Mr. James
# ['Mr.']
# McCarthy, Mr. Timothy J
# ['Mr.']
# Palsson, Master. Gosta Leonard
# ['Master.']
# Johnson, Mrs. Oscar W (Elisabeth Vilhelmina Berg)
# ['Mrs.']
# Nasser, Mrs. Nicholas (Adele Achem)
# ['Mrs.']
# Sandstrom, Miss. Marguerite Rut
# ['Miss.']
# Bonnell, Miss. Elizabeth
# ['Miss.']
# Saundercock, Mr. William Henry
# ['Mr.']
# Andersson, Mr. Anders Johan
# ['Mr.']
# Vestrom, Miss. Hulda Amanda Adolfina
# ['Miss.']
# Hewlett, Mrs. (Mary D Kingcome)
# ['Mrs.']
# Rice, Master. Eugene
# ['Master.']
# Williams, Mr. Charles Eugene
# ['Mr.']
# Vander Planke, Mrs. Julius (Emelia Maria Vandemoortele)
# ['Mrs.']
# Masselmani, Mrs. Fatima
# ['Mrs.']
# Fynney, Mr. Joseph J
# ['Mr.']
# Beesley, Mr. Lawrence
# ['Mr.']
# ...

# %%
import re 

string = "(Dave)"
re.sub("[\W]","",string)
# Out:
# 'Dave'

# %%
import re 

pattern = re.compile("D.A")

pattern.search("DCA")
pattern.search("dca")
pattern.search("d0A DIA 0011")
# Out:
# <re.Match object; span=(4, 7), match='DIA'>

# %%
import re 
pattern01 = re.compile("D?A")
pattern01.search("DDA")
pattern01.search("DDDDDDDDDDA")
# Out:
# <re.Match object; span=(9, 11), match='DA'>

# %%
import re 

pattern02 = re.compile("D*A")
pattern02.search("DDDDDA")
# Out:
# <re.Match object; span=(0, 6), match='DDDDDA'>

# %%
import re 

pattern03 = re.compile("D+A")
pattern03.search("DDDDDDDDDDDDA")
# Out:
# <re.Match object; span=(0, 13), match='DDDDDDDDDDDDA'>

# %%
import re

pattern04 = re.compile("AD{2}A")

pattern04.search("ADDA")
# Out:
# <re.Match object; span=(0, 4), match='ADDA'>

# %%
import re 
pat05 = re.compile("(AD){2,6}A")
pat05.search("ADADADADA")
# Out:
# <re.Match object; span=(0, 9), match='ADADADADA'>

# %%
pat06 = re.compile("[a-g]")
pat06.search("opjertpojeta")
# Out:
# <re.Match object; span=(3, 4), match='e'>

# %%
pat07 = re.compile("[a-zA-Z0-9]")
pat07.search("1234-=-=")
# Out:
# <re.Match object; span=(0, 1), match='1'>

# %%
pat08 = re.compile("[^a-zA-Z0-9]")
pat08.search("1234124=124124")
# Out:
# <re.Match object; span=(7, 8), match='='>

# %%
pat08 = re.compile("[가-힣ㄱ-ㅎ]")
pat08.search("1223ㄴ123")
# Out:
# <re.Match object; span=(4, 5), match='ㄴ'>

# %%
pat09 = re.compile("[가-힣]")
pat09.search("김")
# Out:
# <re.Match object; span=(0, 1), match='김'>

# %%
pat10 = re.compile("[a-z]+")
matched = pat10.match("aveD")
matched
searched = pat10.search("Dave")
searched
# Out:
# <re.Match object; span=(1, 4), match='ave'>

# %%
import re 
pat11 = re.compile("[a-z]+")
findalled = pat11.findall("Game of Life in Python")

findalled
# Out:
# ['ame', 'of', 'ife', 'in', 'ython']

# %%
pat12 = re.compile("[a-z]+")
findalled1 = pat12.findall("GaME")

if len(findalled1) > 0: 
    print("정규표현식에 맞는 문자열이 존재함")
else: 
    print("정규표현식에 맞는 문자열이 존재하지 않음")
# Out:
# 정규표현식에 맞는 문자열이 존재함

# %%
pat13 = re.compile(":")

splited = pat13.split("python:java")
splited
# Out:
# ['python', 'java']

# %%
pat14 = re.compile("[A-Z]{2}")

splited1 = pat14.split("python VS java")
splited1
# Out:
# ['python ', ' java']

# %% [markdown]
# #### 정규표현식 미션
# - "801210 - 1011323" 주민번호 가운데 - 를 *로 교체 하여 출력

# %%
num= "801210 - 1011323"
pat15 = re.compile(" - ")
subbed = pat15.sub("*",num)

print(subbed)
# Out:
# 801210*1011323

# %% [markdown]
# 엑셀파일 가져오기 -> B열의 정보를 모두 가져오기 -> 반복문으로 뒷자리를 전부 *로 바꾸기

# %%
import openpyxl 
import re

wb = openpyxl.load_workbook("data_kr.xlsx")
ws = wb.active 

pattern = re.compile("[0-9]{7}")
test = pattern.sub("*******",idnum)
test
# pattern01 = re.compile("-")
# splitted = pattern01.split(idnum)[1]

# pattern02 = re.compile("[0-9]")
# replaced = pattern02.sub("*",splitted)

# print(splitted[0],replaced)
# Out:
# '800215-*******'
