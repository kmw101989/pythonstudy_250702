# %%
import json 

data = """
{
    "id" : "01","language" : "python", "edition" : "third", "author":"david",
    "history":
        [
            {
                "date:"2025-07-16",
                "item" : "iphone"
            },
            {
                "date":"2025-03-11",
                "item":"android"
        ]
}
"""

json_data = jason.loads(data)
print(json_data["history"])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[7], line 20
#       3 data = """
#       4 {
#       5     "id" : "01","language" : "python", "edition" : "third", "author":"david",
#    (...)
#      16 }
#      17 """
#      19 json_data = data
# ---> 20 print(json_data["history"])
#
# TypeError: string indices must be integers, not 'str'
