# %%
import json 

data = """
{
    "id" : "01","language" : "python", "edition" : "third", "author":"david",
    "history":
        [
            {
                "date":"2025-07-16",
                "item" : "iphone"
            },
            {
                "date":"2025-03-11",
                "item":"android"
            }
        ]
}
"""

json_data = json.loads(data)
print(json_data["history"][0]["date"])
# Out:
# 2025-07-16

# %%
import json

data = """
{
     "lastBuildDate": "Wed, 16 Jul 2025 13:19:21 +0900",
    "total": 1261632,
    "start": 1,
    "display": 10,
    "items": [
        {
            "title": "[비비앙] 월넛크릭그린 오 드 퍼퓸 EDP 10ml 20250423-2",
            "link": "https://link.musinsa.com/app/goods/4442601?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}",
            "image": "https://shopping-phinf.pstatic.net/main_5038779/50387791565.jpg",
            "lprice": "41900",
            "hprice": "",
            "mallName": "무신사",
            "productId": "50387791565",
            "productType": "2",
            "brand": "비비앙",
            "maker": "",
            "category1": "화장품/미용",
            "category2": "향수",
            "category3": "여성향수",
            "category4": ""
        },
         {
            "title": "[보니데] V&amp;A 커버업 랩 수영복 그린(프리) P00000IK",
            "link": "https://link.musinsa.com/app/goods/1968765?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}",
            "image": "https://shopping-phinf.pstatic.net/main_5280188/52801887678.jpg",
            "lprice": "84990",
            "hprice": "",
            "mallName": "무신사",
            "productId": "52801887678",
            "productType": "2",
            "brand": "보니데",
            "maker": "",
            "category1": "스포츠/레저",
            "category2": "수영",
            "category3": "여성수영복",
            "category4": "원피스수영복"
        },
        {
            "title": "[피지컬가먼츠] P2407 메쉬배색 기능성 오버핏반팔 [블랙] P2407",
            "link": "https://link.musinsa.com/app/goods/4128907?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}",
            "image": "https://shopping-phinf.pstatic.net/main_4777637/47776373129.jpg",
            "lprice": "26890",
            "hprice": "",
            "mallName": "무신사",
            "productId": "47776373129",
            "productType": "2",
            "brand": "피지컬가먼츠",
            "maker": "",
            "category1": "패션의류",
            "category2": "남성의류",
            "category3": "티셔츠",
            "category4": ""
        }
    ]
}
"""
json_data = json.loads(data)
print(json_data["items"][0]["title"])
# Out:
# [비비앙] 월넛크릭그린 오 드 퍼퓸 EDP 10ml 20250423-2

# %%
import json
import requests
from bs4 import BeautifulSoup as bs 
import pprint #출력결과를 깔끔하게 만들어주는 라이브러리 (prettier print)
client_id = "BFV2agAgdAzprP1qAKRf"
client_secret = "RPlvNL2GSu"

naver_open_api = "https://openapi.naver.com/v1/search/shop.json?query=무신사"
header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}

res = requests.get(naver_open_api, headers=header_params)

if res.status_code ==200 :
    test = res.json()
    # pprint.pp(test)
    # print(test["items"][0]["title"])
    for index, item in enumerate(test["items"],start=1):
        print(index,item["title"] , item["link"])
else :
    print("err", res.status_code)
# Out:
# 1 [비비앙] 월넛크릭그린 오 드 퍼퓸 EDP 10ml 20250423-2 https://link.musinsa.com/app/goods/4442601?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# 2 [보니데] V&amp;A 커버업 랩 수영복 그린(프리) P00000IK https://link.musinsa.com/app/goods/1968765?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# 3 [피지컬가먼츠] P2407 메쉬배색 기능성 오버핏반팔 [블랙] P2407 https://link.musinsa.com/app/goods/4128907?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# 4 [마뗑킴] ACCORDION MINI BAG IN SILVER MK2400BG730MSV https://link.musinsa.com/app/goods/3024801?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# 5 [토앤토] x 로우클래식 플립플랍 Zerovity 크림 Z-FF-LCCR https://link.musinsa.com/app/goods/3320672?utm_source=naver_jisicshopping&utm_medium=sh&source=NVSH&utm_term={keyword}&utm_content={ad_group}
# ...

# %%
import json
import requests
from bs4 import BeautifulSoup as bs 
import pprint #출력결과를 깔끔하게 만들어주는 라이브러리 (prettier print)
import openpyxl

client_id = "BFV2agAgdAzprP1qAKRf"
client_secret = "RPlvNL2GSu"

start, num =1,0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width =100
excel_sheet.column_dimensions["C"].width =100
excel_sheet.append(["No","제목","링크"])

for index in range(10):
    start_num = start+100*index
    naver_open_api = "https://openapi.naver.com/v1/search/shop.json?query=키보드&display=100&start="+str(start_num)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_params)
    
    if res.status_code ==200 :
        test = res.json()
        # pprint.pp(test)
        # print(test["items"][0]["title"])
        for item in test["items"]:
            num += 1
            excel_sheet.append([num, item["title"] , item["link"]])
            print(num, item["title"] , item["link"])
    else :
        print("err", res.status_code)

excel_file.save("shopping_with_키보드.xlsx")
excel_file.close()
# Out:
# 1 프리플로우 아콘 AK74 104키 유무선 기계식 <b>키보드</b> 마카롱, 저소음 눈송이축 https://search.shopping.naver.com/catalog/54968379040
# 2 지클릭커 오피스프로 OPK50 사일런스 M RGB 무소음 방수 <b>키보드</b> Greenwich CR1, 멤브레인 https://search.shopping.naver.com/catalog/53683755077
# 3 지클릭커 오피스프로 저소음 무선 <b>키보드</b> WK10 블랙, 멤브레인 https://search.shopping.naver.com/catalog/53527631593
# 4 앱코 MK108 저소음 멤브레인 <b>키보드</b> 오트밀, 멤브레인 https://search.shopping.naver.com/catalog/53527806224
# 5 게이밍 기계식 <b>키보드</b> 앱코 K640 청축 배그 롤 피시방 서든어택 스타 사무용 업무용 https://smartstore.naver.com/main/products/5644036525
# 6 아이패드 블루투스<b>키보드</b> 애플 갤럭시탭 태블릿 노트북 맥북 미니 무선 <b>키보드</b> 휴대용 38 https://smartstore.naver.com/main/products/4480526635
# 7 앱코 AS104 오피스네비게이터 3모드 기계식 <b>키보드</b> 화이트, 딥 사운드축 https://search.shopping.naver.com/catalog/53530167724
# 8 QSENN Q104 PBT 블루퍼플, 퍼플축 https://search.shopping.naver.com/catalog/54748753441
# 9 커세어 K70 PRO TKL MGX 래피드트리거 게이밍 기계식 <b>키보드</b> 화이트, 마그네틱축 https://search.shopping.naver.com/catalog/53529119864
# ...

# %%
import json
import requests
from bs4 import BeautifulSoup as bs 
import pprint #출력결과를 깔끔하게 만들어주는 라이브러리 (prettier print)
import openpyxl

client_id = "BFV2agAgdAzprP1qAKRf"
client_secret = "RPlvNL2GSu"

start, num =1,0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width =100
excel_sheet.column_dimensions["C"].width =100
excel_sheet.append(["No","제목","링크","최저가","브랜드","메이커"])

for index in range(10):
    start_num = start+100*index
    naver_open_api = "https://openapi.naver.com/v1/search/shop.json?query=키보드&display=100&start="+str(start_num)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_params)
    
    if res.status_code ==200 :
        test = res.json()
        # pprint.pp(test)
        # print(test["items"][0]["title"])
        for item in test["items"]:
            num += 1
            excel_sheet.append([num, item["title"] , item["link"],item["lprice"],item["brand"],item["maker"]])
            print(num, item["title"] , item["link"])
    else :
        print("err", res.status_code)

excel_file.save("shopping_with_키보드2.xlsx")
excel_file.close()
# Out:
# 1 프리플로우 아콘 AK74 104키 유무선 기계식 <b>키보드</b> 마카롱, 저소음 눈송이축 https://search.shopping.naver.com/catalog/54968379040
# 2 지클릭커 오피스프로 OPK50 사일런스 M RGB 무소음 방수 <b>키보드</b> Greenwich CR1, 멤브레인 https://search.shopping.naver.com/catalog/53683755077
# 3 지클릭커 오피스프로 저소음 무선 <b>키보드</b> WK10 블랙, 멤브레인 https://search.shopping.naver.com/catalog/53527631593
# 4 앱코 MK108 저소음 멤브레인 <b>키보드</b> 오트밀, 멤브레인 https://search.shopping.naver.com/catalog/53527806224
# 5 게이밍 기계식 <b>키보드</b> 앱코 K640 청축 배그 롤 피시방 서든어택 스타 사무용 업무용 https://smartstore.naver.com/main/products/5644036525
# 6 아이패드 블루투스<b>키보드</b> 애플 갤럭시탭 태블릿 노트북 맥북 미니 무선 <b>키보드</b> 휴대용 38 https://smartstore.naver.com/main/products/4480526635
# 7 앱코 AS104 오피스네비게이터 3모드 기계식 <b>키보드</b> 화이트, 딥 사운드축 https://search.shopping.naver.com/catalog/53530167724
# 8 QSENN Q104 PBT 블루퍼플, 퍼플축 https://search.shopping.naver.com/catalog/54748753441
# 9 커세어 K70 PRO TKL MGX 래피드트리거 게이밍 기계식 <b>키보드</b> 화이트, 마그네틱축 https://search.shopping.naver.com/catalog/53529119864
# ...

# %%
import json
import requests
from bs4 import BeautifulSoup as bs 
import pprint #출력결과를 깔끔하게 만들어주는 라이브러리 (prettier print)
import openpyxl

client_id = "BFV2agAgdAzprP1qAKRf"
client_secret = "RPlvNL2GSu"

naver_open_api = "https://openapi.naver.com/v1/search/shop.json?query=키보드&display=100"
header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
res = requests.get(naver_open_api, headers=header_params)

pprint.pp(res.json())
# Out:
# {'lastBuildDate': 'Wed, 16 Jul 2025 15:31:09 +0900',
#  'total': 3569802,
#  'start': 1,
#  'display': 100,
#  'items': [{'title': '프리플로우 아콘 AK74 104키 유무선 기계식 <b>키보드</b> 마카롱, 저소음 눈송이축',
#             'link': 'https://search.shopping.naver.com/catalog/54968379040',
#             'image': 'https://shopping-phinf.pstatic.net/main_5496837/54968379040.20250526112405.jpg',
#             'lprice': '85000',
#             'hprice': '',
#             'mallName': '네이버',
#             'productId': '54968379040',
#             'productType': '1',
#             'brand': '프리플로우',
#             'maker': '프리플로우',
#             'category1': '디지털/가전',
#             'category2': '주변기기',
#             'category3': '키보드',
#             'category4': '무선키보드'},
#            {'title': '지클릭커 오피스프로 OPK50 사일런스 M RGB 무소음 방수 <b>키보드</b> Greenwich '
#                      'CR1, 멤브레인',
#             'link': 'https://search.shopping.naver.com/catalog/53683755077',
# ...

# %%
import json
import requests
from bs4 import BeautifulSoup as bs 
import pprint #출력결과를 깔끔하게 만들어주는 라이브러리 (prettier print)
import openpyxl

url = "https://api.themoviedb.org/3/movie/now_playing?language=ko-KR&page=1"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1NzRmOGMzZTgxY2YzZjk2NzFhZmJkZTZhYzVhNmIyYSIsIm5iZiI6MTc1MjY0ODM3OS4wNjgsInN1YiI6IjY4Nzc0YWJiMmE0MWY4ODIwOGJhMThkNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.nJ0zn_ojlPslswe6BCk0IiCDuArT9lmoJc2F4Nq5YXg"
}

response = requests.get(url, headers=headers)


excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width =100
excel_sheet.column_dimensions["C"].width =100
excel_sheet.append(["제목","개봉일","평점","줄거리"])

url = "https://api.themoviedb.org/3/movie/now_playing?language=ko-KR&page=5"
headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJhbGciOiJIUzI1NiJ9.eyJhdWQiOiI1NzRmOGMzZTgxY2YzZjk2NzFhZmJkZTZhYzVhNmIyYSIsIm5iZiI6MTc1MjY0ODM3OS4wNjgsInN1YiI6IjY4Nzc0YWJiMmE0MWY4ODIwOGJhMThkNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.nJ0zn_ojlPslswe6BCk0IiCDuArT9lmoJc2F4Nq5YXg"
}
response = requests.get(url, headers=headers)
    
if response.status_code ==200 :
    test = response.json()
    # pprint.pp(test)
    # print(test["items"][0]["title"])
    for item in test["results"]:
        excel_sheet.append([item["title"] , item["release_date"],item["vote_average"],item["overview"]])
        print(item["title"] , item["release_date"],item["vote_average"],item["overview"])
else :
    print("err", res.status_code)

excel_file.save("tmdb.xlsx")
excel_file.close()
# Out:
# 斗罗大陆剧场版：剑道尘心​ 2025-07-12 9.0
# 오만과 편견 2005-09-16 8.065 베넷 가의 다섯 자매 중 둘째인 엘리자베스는 사랑하는 사람과의 결혼을 믿는 자존심 강하고 영리한 소녀이다. 부유하고 명망있는 가문의 신사 빙리와 그의 친구 다아시가 여름 동안 대저택에 머물게 되고, 댄스 파티에서 처음 만난 엘리자베스와 다아시는 서로에게서 눈을 떼지 못한다. 다아시는 아름답고 지적인 그녀의 매력에 점점 빠져들고, 폭우가 쏟아지는 날 비바람이 몰아치는 언덕에서 가슴 속 깊은 곳에 담아둔 뜨거운 사랑을 그녀에게 고백한다. 하지만 다아시가 빙리와 제인의 결혼을 제인이 명망있는 가문 출신이 아니라는 이유로 반대한 것을 알게 되자, 그를 오만하고 편견에 가득 찬 속물로 여기며 외면하는데...
# 더 달콤살벌한 2025-06-19 5.3 파워 커플인 재키와 제이피. 유아용품 광고 계약을 따내기 위해 완벽한 부모의 모습을 연기해야 한다. 하지만 일만 보고 달려온 두 사람에겐 부모 노릇이 쉽지 않다.
# 레옹 1994-09-14 8.301 한 손엔 우유 2팩이 든 가방, 다른 한 손엔 화분을 들고 뿌리 없이 떠도는 킬러 레옹은 어느 날 옆 집 소녀 마틸다의 일가족이 몰살 당하는 것을 목격한다. 그 사이 심부름을 갔다 돌아 온 마틸다는 가족들이 처참히 몰살 당하자 레옹에게 도움을 청한다. 가족의 원수를 갚기 위해 킬러가 되기로 결심한 12세 소녀 마틸다는 레옹에게 글을 알려주는 대신 복수하는 법을 배우고, 그 사이 레옹에 대한 사랑을 키워나간다. 드디어 그녀는 가족을 죽인 사람이 부패한 마약 경찰 스탠스임을 알게 되고, 홀로 그의 사무실로 향하게 되는데...
# Daniela Forever 2025-02-21 7.6
# 无名之辈：否极泰来 2025-06-26 7.5
# ...

# %%
import json
import requests
from bs4 import BeautifulSoup as bs 
import pprint #출력결과를 깔끔하게 만들어주는 라이브러리 (prettier print)
import openpyxl

client_id = "BFV2agAgdAzprP1qAKRf"
client_secret = "RPlvNL2GSu"

start, num =1,0

excel_file = openpyxl.Workbook()
excel_sheet = excel_file.active
excel_sheet.column_dimensions["B"].width =100
excel_sheet.column_dimensions["C"].width =100
excel_sheet.append(["No","제목","링크","최저가","브랜드","메이커"])

for index in range(10):
    start_num = start+100*index
    naver_open_api = "https://openapi.naver.com/v1/search/shop.json?query=키보드&display=100&start="+str(start_num)
    header_params = {"X-Naver-Client-Id":client_id, "X-Naver-Client-Secret":client_secret}
    res = requests.get(naver_open_api, headers=header_params)
    
    if res.status_code ==200 :
        test = res.json()
        # pprint.pp(test)
        # print(test["items"][0]["title"])
        for item in test["items"]:
            num += 1
            excel_sheet.append([num, item["title"] , item["link"],item["lprice"],item["brand"],item["maker"]])
            print(num, item["title"] , item["link"])
    else :
        print("err", res.status_code)

excel_file.save("shopping_with_키보드2.xlsx")
excel_file.close()

# %%
print(response.json())
# Out:
# {'dates': {'maximum': '2025-07-23', 'minimum': '2025-06-11'}, 'page': 1, 'results': [{'adult': False, 'backdrop_path': '/nKyBbFSooRPTJVqjrDteD1lF733.jpg', 'genre_ids': [28, 12, 18], 'id': 1011477, 'original_language': 'en', 'original_title': 'Karate Kid: Legends', 'overview': '서로 다른 세대의 스승 미스터 한(성룡)과 다니엘 라루소(랄프 마치오)가 소년 ‘리’를 중심으로 힘을 합치며 펼쳐지는 무술 성장 드라마. 과거의 철학과 기술을 계승한 두 사부는 삶의 벽에 부딪힌 리에게 가라데의 진정한 의미를 전하며 함께 성장한다.', 'popularity': 629.7943, 'poster_path': '/AEgggzRr1vZCLY86MAp93li43z.jpg', 'release_date': '2025-05-08', 'title': '가라데 키드: 레전드', 'video': False, 'vote_average': 7.309, 'vote_count': 405}, {'adult': False, 'backdrop_path': '/qtSY2SAL5QApuCUD0sXqyzgHYnl.jpg', 'genre_ids': [28, 35, 80, 9648], 'id': 1374534, 'original_language': 'nl', 'original_title': "Bad Boa's", 'overview': '동네 치안을 위해 헌신하는 열정 넘치는 단속 요원과 이 지역으로 좌천된 저돌적인 전직 형사. 두 사람이 어쩔 수 없이 한 팀이 되면서 로테르담 거리에 예측 불허의 상황이 펼쳐진다.', 'popularity': 495.8851, 'poster_path': '/poRvoGlxotJ5YDzLCGCUZHOF8x.jpg', 'release_date': '2025-07-1
# ...
