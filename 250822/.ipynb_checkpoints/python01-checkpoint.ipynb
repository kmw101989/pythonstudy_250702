# %%
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time,re
import pandas as pd

service = Service(ChromeDriverManager().install())
options = Options()
# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--start-maximized")
options.add_argument("--window-size=1920x1080")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

category_urls = {
    "여성의류":"https://display.wconcept.co.kr/rn/best?displayCategoryType=10101&displaySubCategoryType=ALL&gnbType=Y",
    "가방":"https://display.wconcept.co.kr/rn/best?displayCategoryType=10102&displaySubCategoryType=ALL&gnbType=Y",
    "신발":"https://display.wconcept.co.kr/rn/best?displayCategoryType=10103&displaySubCategoryType=ALL&gnbType=Y",
    "엑세서리":"https://display.wconcept.co.kr/rn/best?displayCategoryType=10104&displaySubCategoryType=ALL&gnbType=Y"
}
all_data = []

def extract_product_id_from_imgsrc(src: str) -> str | None:
    if not src: 
        return None 
    m = re.search(r"/(\d+)(?:[_\.][^/?]+)?(?:\?.*)?$", src)
    return m.group(1) if m else None 

def build_product_url(pid: str| None) -> str : 
    return  f"https://www.wconcept.co.kr/Product/{pid}" if pid else "" 

for cat_name, url in category_urls.items() : 
    driver.get(url)
    time.sleep(2)

    for _ in range(2) : 
        driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
        time.sleep(1)
        
    products = driver.find_elements(By.CSS_SELECTOR, "div.product-item.item.type-all")[:100]
    for product in products : 
        try: 
            name = product.find_element(By.CSS_SELECTOR, "span.prdc-title span.text.detail").text.strip()
            try:
                img = product.find_element(By.CSS_SELECTOR,"button.area-img img")
                src = img.get_attribute('src')
                pid = extract_product_id_from_imgsrc(src)
                url = build_product_url(pid)
            except :
                url = ""
            try:
                review_info = product.find_element(By.CSS_SELECTOR,"span.area-info span.text.cnt").text
                review_count = int(re.sub(r"[^\d]","",review_info)) if review_info else 0 
            except:
                review_count = 0 

            try :
                rating_text = product.find_element(By.CSS_SELECTOR,"span.area-info em.score").text
                review_avg = float(re.findall(r"[0-9.]+",rating_text)[0])
            except:
                review_avg = 0.0

            all_data.append({
                "카테고리": cat_name,
                "상품명": name,
                "URL": url,
                "리뷰 수": review_count,
                "평균평점": review_avg
            })
                
        except Exception as e :
            print("에러발생 :",e)
            continue 

driver.quit()

df = pd.DataFrame(all_data)
df_top100 = df.sort_values(by="리뷰 수",ascending=False).head(100).reset_index(drop=True)

category_summary = df.groupby("카테고리").agg({
    "리뷰 수"    :"sum", 
    "평균평점"   :"mean"
}).reset_index()

print(f""" 
상위 100개 상품:
{df_top100.head()}

카테고리별 통계:
{category_summary}
""")
# Out:
#
# 상위 100개 상품:
#    카테고리                                    상품명  \
# 0    신발                OORIGINAL BLACK - 조리 블랙
# 1    가방  [14%쿠폰] [단독] Panier Petit Bag_6colors
# 2  엑세서리   [단독] Round Logo Ball Cap (10 Colors)
# 3  엑세서리           [단독]BT8032 티디 스퀘어 버클 벨트 18mm
# 4  여성의류                       실켓 코튼 티셔츠_8color
#
#                                             URL  리뷰 수  평균평점
# 0  https://www.wconcept.co.kr/Product/301721294  8478   5.0
# 1  https://www.wconcept.co.kr/Product/301756891  3730   5.0
# 2  https://www.wconcept.co.kr/Product/301628486  3682   4.9
# 3  https://www.wconcept.co.kr/Product/304460283  3131   4.9
# 4  https://www.wconcept.co.kr/Product/301218440  2968   4.9
#
# 카테고리별 통계:
#    카테고리   리뷰 수   평균평점
# 0    가방  24218  4.267
# 1    신발  27342  4.281
# 2  엑세서리  30519  4.016
# 3  여성의류  31521  4.435

# %%
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time,re
import pandas as pd

service = Service(ChromeDriverManager().install())
options = Options()
# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--start-maximized")
options.add_argument("--window-size=1920x1080")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

for item in all_data:
    url = item["URL"]
    driver.get(f"{url}#review")
    time.sleep(1)
    reviews =driver.find_elements(By.CSS_SELECTOR,"p.pdt_review_text")
    for review in reviews :
        product_review = review.text 

driver.quit()
# Out:
# ---------------------------------------------------------------------------
# InvalidSessionIdException                 Traceback (most recent call last)
# Cell In[31], line 25
#      23 driver.get(f"{url}#review")
#      24 time.sleep(1)
# ---> 25 reviews =driver.find_elements(By.CSS_SELECTOR,"p.pdt_review_text")
#      26 for review in reviews :
#      27     product_review = review.text
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webdriver.py:963, in WebDriver.find_elements(self, by, value)
#     959     return self.execute_script(find_element_js, by.to_dict())
#     961 # Return empty list if driver returns null
#     962 # See https://github.com/SeleniumHQ/selenium/issues/4555
# --> 963 return self.execute(Command.FIND_ELEMENTS, {"using": by, "value": value})["value"] or []
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\webdriver.py:454, in WebDriver.execute(self, driver_command, params)
#     451 response = cast(RemoteConnection, self.command_executor).execute(driver_command, params)
#     453 if response:
# --> 454     self.error_handler.check_response(response)
#     455     response["value"] = self._unwrap_value(response.get("value", None))
#     456     return response
#
# File ~\AppData\Roaming\Python\Python313\site-packages\selenium\webdriver\remote\errorhandler.py:232, in ErrorHandler.check_response(self, response)
#     230         alert_text = value["alert"].get("text")
#     231     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 232 raise exception_class(message, screen, stacktrace)
#
# InvalidSessionIdException: Message: invalid session id: session deleted as the browser has closed the connection
# from disconnected: not connected to DevTools
#   (Session info: chrome=139.0.7258.128); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#invalidsessionidexception
# Stacktrace:
# 	GetHandleVerifier [0x0x6cffc3+65331]
# 	GetHandleVerifier [0x0x6d0004+65396]
# 	(No symbol) [0x0x4c3f63]
# 	(No symbol) [0x0x4b38e0]
# 	(No symbol) [0x0x4d1709]
# 	(No symbol) [0x0x537e4c]
# 	(No symbol) [0x0x5524d9]
# 	(No symbol) [0x0x5312d6]
# 	(No symbol) [0x0x500910]
# 	(No symbol) [0x0x501784]
# 	GetHandleVerifier [0x0x9138b3+2439203]
# 	GetHandleVerifier [0x0x90eae2+2419282]
# 	GetHandleVerifier [0x0x6f712a+225434]
# 	GetHandleVerifier [0x0x6e6e08+159096]
# 	GetHandleVerifier [0x0x6edd5d+187597]
# 	GetHandleVerifier [0x0x6d7ad8+96840]
# 	GetHandleVerifier [0x0x6d7c62+97234]
# 	GetHandleVerifier [0x0x6c277a+9962]
# 	BaseThreadInitThunk [0x0x75f4fcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x777282ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x7772827e+238]

# %%
from selenium import webdriver 
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import time

service = Service(ChromeDriverManager().install())
options = Options()
# options.add_argument("--headless")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("--start-maximized")
options.add_argument("--window-size=1920x1080")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/139.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")

driver = webdriver.Chrome(service=service, options=options)

for item in all_data:
    url = item["URL"]
    driver.get(f"{url}#review")
    time.sleep(1)
    
    reviews = driver.find_elements(By.CSS_SELECTOR, "p.pdt_review_text")
    product_reviews = []
    for review in reviews:
        txt = review.text.strip()
        if txt:
            product_reviews.append(txt)
    
    # 상품명과 함께 출력
    print("="*50)
    print(f"상품명: {item['상품명']}")
    print(f"URL: {url}")
    print("리뷰:")
    for r in product_reviews:
        print("-", r)

driver.quit()
# Out:
# ==================================================
# 상품명: [72H팝업] [단독]캐시미어 피크드 칼라 더블 롱코트_2colors
# URL: https://www.wconcept.co.kr/Product/306038291
# 리뷰:
# - 지난 겨울에 살말 고민만하다 품절되서 구매 못했었는데 이번에 다시 오픈된거 보자마자 빨리 구매했어요!
# 배송받자마자 입어봤는데 핏도 멋스럽고 소재도 좋네여 ... 역시 고민한 시간이 아깝지 않은 퀄리티에요ㅜㅜ겨울이 기다려져요 ㅎㅎ
# - 작년에 멜란지그레이 컬러 구매하고 너무 잘 입어서 프리오픈 떠서 할인 받아 구매했는데 컬러도 고급스럽고 퀄리티 좋아서 오래 입을 수 있을 것 같아요!!
# 회사로 배송지 선택을 잘못해서.. 회사에서 한 번 입어봤는데 팀원들 다 예쁘다고 해서 좋은 소비한 것 같아 기분 좋았네용..ㅎㅎㅎ
# - 작년부터 사고 싶었는데 품절이라 아쉬웠던 제품이라 이번에 미리 알림 걸어두고 구매했어요
# 클래식하고 오래 입을 수 있는 디자인이라 군더더기 없이 핏이 딱 떨어집니다
# 소재도 부드러워서 올겨울 내내 잘 입을 것 같아요
# - 살짝 크긴하지만 오버핏으로 여유롭게 이뻐요
# 기장도 긴편인데 뒤에 절개가 들어있어 부담스럽지 않고
# 소재도 탄탄하고 특히 색감이 너무 맘에들어요!!
# - 이거 입으면 사람이 길어보이고 태가 나요!! 소재도
# 좋고 카라가 커서 얼굴 작아보이는 효과는 덤 ㅎㅎ
# 올겨울 내내 교복처럼 입고 댕겼어용
# - 가격대비 코트 재질이 좋은것 같아요~
# 약간 오버핏이고 롱이라 저에게는 좀 크고 긴 느낌이지만 재질이 좋고 약간 밝은 회색이라 화사하게 입을수 있을것 같아요~♡
# ==================================================
# 상품명: 샤론 슬림 니트 가디건(멜란지그레이)
# URL: https://www.wconcept.co.kr/Product/307350085
# 리뷰:
# - 진짜 얇네요
# 그래서 여름에 입기 더 좋은거 같아용~~~
# 소재도 부들부들하고
# 맘에 들어요
# - 소재아주좋습니다 깔별로 구입
# 길이도좋고 소재가 얇아 오래못입을까봐 걱정 ㅋㅋ
# - 소재아주좋습니다 깔별로 구입
# 길이도좋고 소재가 얇아 오래못입을까봐 걱정 ㅋㅋ
# - 소매가 길어서 너무 좋네요 ㅎ 요즘 크롭이 너무 많이 나오는데, 기장도 적당해 넘 맘에 들어요
# - 살짝 큰데 예뻐요 작은 사이즈로 추가 주문해서 입으려구용 ㅎ 예쁜건 두세장씩 소장해야합니다
# - 진짜.. 너무 예뻐서 엄마도 주문해 드렸어요, 슬림핏인데 바디 라인이 부담스럽게 드러나는건 아니라 멋스럽게 입기 좋아요
# ==================================================
# 상품명: [72H팝업] 캐시미어 발마칸 핸드메이드 코트_3colors
# URL: https://www.wconcept.co.kr/Product/306038292
# 리뷰:
# - 기본템 필요해서 삿는데 너무 잘 입었어요. 딱 원하는 적당한 핏에 길이여서 마음에 들었어요. 너무 무겁지도 않고 두께에 비해 따뜻해서 좋았어요
# - 너무 부드럽고 핏도 예뻐요 대만족입니다!
# - 저렴한 느낌 없이 깔끔해요
# - 핸드메이드라 그런지 ㅅ생각보다 얇고 퍼지는 스타일이라 청바지 보다는 치마류랑 잘어울리네요 옷 자체는 고급져요
# - 소재뷰드럽고 좋은데 저한테 많이커요!! ㅋㅋㅋ그래도 이뻐서 품어요~!!
# - 사이즈도 적당하고 좋습니다!
# ==================================================
# 상품명: [여울PICK]LOND WAIST TUCK T-SHIRT (Z-BL-4225)
# URL: https://www.wconcept.co.kr/Product/305818731
# 리뷰:
# - 저한테 안 어울리네요.
# 제 체형은 어깨가 좁고 상체가 많이 왜소한 편이에요.
#
# 1. 보트넥이 어깨 보안해주지 않는 느낌
#
# 2. 품이 큰 편이라 몸이 더 부해 보임
# (드레이프도 그렇게 보이게 하는듯)
#
# 3. 빼입을 해야할 거 같은데 이런 스타일이 처음이라 그런지 이상함.. 허리가 더 길어 보임
#
# 4. 드레이프 접힌 부분이 아무래도 천이 더 들어갔다고 더움
#
# 이런 스타일이 잘 어울리는 분들한테는 괜찮을 거 같긴 하지만, 저는 별로였어요ㅠ
# - 옷에 셔링이 잡혀있어서 여성스런 느낌도 나고 디자인적으로도 예뻐요. 옷 아래부분이 사선으로 되어있어서 똥배 가리는데에도 좋아요.
# - 출근룩 옷으로 딱이에요!!!
# 날씬해보이고 ~ 넘 편해보이지도 않아서 좋네영 ㅎㅎ
# - 진짜 너무 예빠요 소매가 짦긴한데 적당히 팔뚝 얇아보이는 디자인이라 여리여리해보여요 ㅎ
# - 사서 잘 입었습니다.
# 편하면서 포인트돼요
# - 착붙고 질이 좋아요
# 모양이 유니크하고 꾸안꾸느낌으로 좋아요
# 뱃살커버도 되고 너무추천합니다
# ==================================================
# 상품명: [15%+5%쿠폰] [단독]UNISEX WAXED COTTON HUNTING JACKET_3 color
# URL: https://www.wconcept.co.kr/Product/307335695
# 리뷰:
# - 피부가 까매서 옷 색상에 되게 민감한데 예전부터 찾아헤매던 카키색이 맞아요! 고급스러워 보이는 컬러고 가을 겨울에 찰떡이에요 내피 배색도 잘 되어있어서 어디가서 옷벗어놓아도 좋아요~ 다만 큰박스 입은거처럼 왜이렇게 뻣뻣하고 부스럭 거릴까요.. 글 중에 왁스처리? 해놨단 말이 있었는데 그래서 그런가봐요 촤르르 부들부들 좋아하는 스퇄이라 조금 아쉬워요 사이즈는 s가 66이란말에 xs했는데 넉넉하게 잘 맞아요 키가 작은데 팔길이도 조금 길다 싶을정도로 맞네요~ 캐주얼하게 점퍼형태 옷이랑 고민하다가 세일해서 던스트로 샀는데 아주 만족합니다
# - 사이즈 고민하다 S어요 오버핏 조아해서 M으로 할까하다가 던스트옷들이 좀 크게 나와서 걍S로했는데 M했으면 너무 클뻔했어요 옷도 빳빳하니 이쁘네요
# - 네이비 샀는데
# 네이비보다 검정에 가까워요! 예쁘고 무난하게 입기 좋습니다~!
# 빨리 가을 오면 좋겠어요
# - 브라운 색상으로 사이즈 진짜 고민 많이 했는데
# 키가 커서 m했는데 아주 찰떡 !
# 평소에도 아우터는 한치수나 두치수 업해서
# 입기때문에 사이즈 아주 굿 좋아요
# - 던스트 신상나와서 바로 구매했어요!
# 아우터는 조금 크게나오는듯해서 XS로 주문했는데 잘 주문한것같아요!! S했으면 어정쩡하게 커서 어색했을것같아요!! 입어봤는데 박시핏에 길이도 넉넉해서 예뻐요!!
# - 예뻐요..! S랑 고민했는데 XS 하길 너무 잘했어요 ! 색도 너무 예쁘고 두루두루 어울릴 거 같아요!
# ==================================================
# 상품명: 스푸마토 언발 블라우스(카키)
# URL: https://www.wconcept.co.kr/Product/307350064
# 리뷰:
# - 제 톤에 맞는 색은 아니지만
# 카키색 넘 맘에 들어서 그냥 샀어요.
# 어울리든 말든 색상, 핏 다 마음에 들어요.
# - 와 너무너무 맘에 드는 블라우스 멋스러운 스탈
# - 그레이쉬블루랑 함께 구매했는데 진짜 가격대비 퀄리티 넘 좋아요. 날씨 살짝 선선해지면 바로 착용해야겠어요. 정장느낌도 강하지만 하의를 조금 캐주얼하게 가도 괜찮을 것 같아요
# - 옷은 너무 예뻐요
# 항상 메무아
# 엇은 이쁜데
# 사고나며누가격이
# 꼭 떨어지더라구요 참 ㅠㅠ
# - 배송도 빠르고 색이랑 디자인 다 화면과 같아요
# - 리오셀 혼방이라 소재가 좋아서 선택했는데
# 부드럽고 가볍고 은은한 광택으로 고급스러워요
# 몸이 무척 편안한 원단이고
# 생각보다는 루즈한 핏감으로 팔도 길고 기장도 길어요
# 랩디자인으로 입는게 확실히 더 이쁘네요
# 부드럽고 가벼운 원단인만큼 힘 없이 차르르 떨어지는 핏이라 흐물흐물 힘없는 원단 싫어하시는분들은
# 원단을 한번 잘 보셔야 할 것 같아요
# 전 텐셀을 무척 좋아하고 안 입은 듯 가볍고
# 터치감이 부들부들한 편안한 원단을 좋아하기에 만족합니다
# 한 여름에도 하늘하늘 시원하고
# 너무너무 가벼워서 좋아요
# 카키색 너무 칙칙할까봐 고민했는데
# 분위기 있고 고급진 색감이예요
# ==================================================
# 상품명: [72H팝업] 캐시미어 울 블랜디드 싱글 하프 코트_3colors
# URL: https://www.wconcept.co.kr/Product/306141668
# 리뷰:
# - 작년에 버터 품절이라 블랙 사서 잘 입고 다녔는데 재입고 알림받고 들어오니 뉴컬러 나왔다해서 무난한 그레이로 샀어요 ㅎㅎ 클래식한 아이템으로 손이 많이 가고 품도 넉넉해서 추울때는 니트입어도 착용감이 편해요 폭 품어줘서 포근한 느낌 ? 소재도 좋아서 매년 입을 수 있겠어요 주변에서 다 예쁘다고 잘어울린다고 그래요 헤어리감이 정말 예술입니다 이제 슬슬 가을 겨울 옷 많이 보이는데 계절이 기다릴정도로 정말 잘산템 ! 월급받으면 버터 컬러도 살래요 ~~~
# - 작년에 인기 많아서 눈여겨 보고있던 코트인데 이번에 새로운 컬러가 많아서 고민하가다 그레이로 픽 했습니다!
# 포켓에 달려있는 로고도 귀엽구,, 무엇보다 소재가 너무 좋아보여요!! 그리고 내부에는 패딩 처리가 되어있어서 한겨울까지 쭉~~ 입을 수 있을거같아요. 당장 입고 다니고 싶어서 얼른 추운 계절이 오면 좋겠어요!
# - 작년에 살까말까 고민하다가 시기를 놓쳤었는데 프리오픈했길래 바로 구입했어요!
# 택배 오자마자 입고있던 옷에다 바로 걸쳐봤는데 잘 어울리네요,,
# 퀄리티도 넘 좋구 유행 안타는 데일리한 디자인이라 오래오래 입을 수 있을 것 같아요.
# 무난하게 착용하려구 그레이 구입했는데 넘 맘에 들어서 버터컬러도 사고싶습니다 ㅎ ㅅㅎ
# - 소재가 너무 부들 부들해서 보풀같이 잘일어나는 건 사실임 근데 두꺼운데 스타일있게 이뻐서 자주손이감 코트빗으로 잘정리해주면 보풀같이 느껴지는것들 정리도 잘되서 굿굿
# - 겨울 내내 엄청 잘 입고 다녔어요 맨날입음 휘뚤마뚤
# - 키가 작아서 하프기장 찾고 있었는데,,
# 마침세일할때 잘 샀어요~~
# 5번정도 입었는데,, 좀 보풀이 일어나긴 해요~
# 그래도 스타일이며 기장, 소재가 맘에 듭니다~
# 오래도록 잘 입을수있었으면 죻겠어요~
# ==================================================
# 상품명: [한정특가] STRIPE EDGELINE WIDE PANTS_GRAY
# URL: https://www.wconcept.co.kr/Product/307363913
# 리뷰:
# - 룩북이 너무 예뻐서 코디한 대로 구매했어요! 재질이 좋고 두께가 가을에 딱 맞을 것 같아요! 키 162인데 기장 참고해주세여 여기서 첨 구매하는데 넘 맘에 드네요ㅎㅎ
# - 진짜 원하던정도의 와이드핏이구 색조합 귀여워서 잘산템입니다ㅋㅋ 가을에 얼른 입구싶어요ㅋㅋ 출근룩으로도 입으려구여ㅋㅋ만조크
# - 사이즈 여유롭게 편해요
# - 배송이 빠릅니다. 가을에 입기 좋은 두께감이고 디자인 등 마음에 듭니다.
# ==================================================
# 상품명: [PRE-OPEN] [NEW컬러추가]NEFF LINEN KNIT (5colors)
# URL: https://www.wconcept.co.kr/Product/305914779
# 리뷰:
# - 사이즈 적당하고 여름에 입기 넘 예뻐요! 살안타템
# - 진짜 예쁨 후회안함 휘뚜루마뚜루 템 이거 말고는 손이안간다 손이안가
# - 할인 기간에 구매했는데 부들부들 모달 소재를 이제서야 알게 되다니! 면 소재 보다 훨씬 좋은 거 같아요. 가격대가 좀 있지만 만족합니다.
# - 성글성글한 짜임의 여름 니트입니다
# 일상생활에서 올나감에 주의해야할것 같으나
# 목라인이 여리여리하게 보이고 소매가 길어
# 너무 좋습니다 ㅠㅠ
# - 제품이 아주 마음에 듭니다.
# - 평소에 살까말까 고민헸던건데 세일하길래 바로 구매했습니다! 증말 왜 많이들 구매하시는지 알겠아요... 완전 여리여리 해보야요!! 지금은 더워서 못입을거같구 날이
# 좀 선선해지면 바로 입을래요~! 색상은 아이보리라기보다는 화이트에 가까워요!
# ==================================================
# 상품명: [30%쿠폰] 클래식 벨트 스트레이트 데님
# URL: https://www.wconcept.co.kr/Product/307377177
# 리뷰:
# - 기존 바지보다 허리가 좀 작게나온거 같은데
# 사이즈 업 할 필요까진 없을거 같아요!
# 그냥 좀 예전보다 딱 맞는정도?
# 기존 바지들은 너무 길었었는데 길이도 약간 짧은거 같아요! 약간 길긴 하지만 딱 좋습니다!
# 가을에 입기 넘 이쁜 색감이에요
# - 바지...그노노이바지는 아묻따 사시면될꺼같아요
# 올여름 바지중 손이 자주 가던게 그노노이라서
# 가을바지 나오자마자 삿는데 후회없이 너무 이뻐요
# 다른거보다 바지 바로받고싶어서 먼저 삿는데 너무 만족이요 바지핏예술이에요
# 티는 그노노이패드티인데 이것도 강추입니다
# ==================================================
# 상품명: Cencel See-Through Classic Shirt - 6COL
# URL: https://www.wconcept.co.kr/Product/305877804
# 리뷰:
# - 핑크색상 구매하고 맘에 들어서 흰색으로 또 구매했습니다. 너무 편하고 시원해요~
# - 시원한 소재+구겨지지 않음+길이 넉넉함 + 가격착함
# - 시원한 소재+구겨지지 않음+길이 넉넉함 + 가격착함
# - 리뷰도 많고 할인하길래 구매했는데 왜 사람들이 많이 사는지 알겠네요 소재도 괜찮고 사이즈나 핏이 괜찮아서 지금 입기 좋네요
# - 핑크 사서 너무 잘 입어서 회이트도 샀아요.
# - 시원한 소재라 여름에도 입기 좋고 나시만 입기 부담스럽거나 에어컨바람 막는용으로도 딱이네요
# ==================================================
# 상품명: [단독NEW컬러] [오늘 출발] Natti Half Sleeve Top
# URL: https://www.wconcept.co.kr/Product/306908505
# 리뷰:
# - 너무예뻐용!! 색상도 좋구 ㅎㅎㅎ 남자친구가 예쁘대요 목이 좀 더운거 빼곤....
# - 핏도 예쁘고 잘 입을 것 같아요. 보풀만 안 일어났으면 좋겠네요ㅎㅎ
# - 색깔이 차분해서 좀 더 성숙한 분위기가 나네요~ 소재도 좋고 참 잘 산 것 같아요
# - 작은느낌이잇고
# 기장이짧아요ㅜㅜ
# 그점이아쉽네요ㅜ
# - 생각보다 원단이 두껍고 사이즈도 작습니다
# 한 여름엔 입기 힘들것 같아요
# 초가을 바람부는 여름 끝자락에 입어볼까 합니다
# - 생각보다 사이즈가 작아요
# 원단도 좀 두껍고 시원하지 않네요
# 찬바람이 부는 여름 끝자락이나 이너웨어로 입어야 할듯 하네요
# ==================================================
# 상품명: Roosa dress (2colors)
# URL: https://www.wconcept.co.kr/Product/306788003
# 리뷰:
# - 베이직한 디자인인데도 소재가 좋아서 그런지 저렴한 느낌 안나서 너무 좋아요! 마음에 듭니다~
# - 사이즈 딱 좋고 뱃살도 완전 코버되고 엄청 날씬해 보입니다.길이는 좀 긴듯하지만 그냥 입어도 될듯하고 너무 맘에 듭니다.
# - 핏도 예쁘고 날씬해보여요 중요한 자리에 입고가기 좋을 것 같아요.
# - 중요한날 입으려고 구매했고 사이즈는 아주 잘맞습니다 ㅋㅋ 큰건 아닌데 적당히 잘 맞아요 베이지인데 크림느낌이 더 강해서 더 이뻐요
# - 이뻐요 우아한 이미지 연출
# 격식있거나 정장 입어야 하는 자리에 여성스러운 느낌 좋고 길이감 있어서 그리 불편하지
# 않고요
# - 55반정도 입는데 너무 타이트하지 않게 맞습니다.
# ==================================================
# 상품명: [한정특가] 뷔스티에 니트 셔츠 4컬러
# URL: https://www.wconcept.co.kr/Product/305963796
# 리뷰:
# - 블랙, 레몬 둘다 샀어요~ 블랙은 정장처럼, 레몬은 캐절하게 입으려고요. 긴팔은 품절이라 아쉽네요
# - 블랙과 레몬 2개 구매했어요~ 블랙은 블랙대로 레몬은 레몬대로 상큼하고 너무 예뻐요. 긴팔은 품절이라 아쉽 니트라고 하지만 시원해요
# - 예뻐요!! 엄청 자연스럽게 예뻐서 마음에 들어요!!
# - 니트쪽과 셔츠쪽 원단이 두껍지 않고 촉감이 너무 좋네요~ 어깨라인도 마음에 듭니다!!
# - 도착하자마자 입어봤는데 너무 이뻐요 정말 잘산거 같아요 굿굿 추천합니다 역시 리뷰가 많은건 이유가 있네요 강추입니다
# - 입어만 봤는데 팔 부분이 금방 구겨지네요. 좀 짧긴 한데 출근룩으로 좋을 듯~!
# ==================================================
# 상품명: [72H팝업] 마레 캐시미어 테일러드 코트 그레이지
# URL: https://www.wconcept.co.kr/Product/301864566
# 리뷰:
# - 블랙색도 사고 싶을만큼 이뻤어요 길이도 길고 격식있는 자리에도 좋고 다 좋을거같네요 이브랜드 코트 자주 살거같아요ㅎ
# - 비주얼 넘 예쁘고 화면이랑 비슷해요 단추 디테일도 예쁩니댱 ㅎㅎ
# - 색감 그레이지~~~ 고급스러워요 회끼도는 아이보리?? 쉽게 볼 수 없는 색상이고 흰색코트가 부담스러운 사람에겐 딱이에요!! 다만 코트가 다소 무거운 부분도 있고 다크한 색상의 코트보다는 오염이 잘 돼서 아무래도 조심히 입긴 해야해요
# - 사이즈 딱 맞아요
# - 세일 때 정말 좋은 가격으로 구매했어요. 화이트 코트 장만하려고 많이 봤는데 부담스럽게 너무 하얗거나 아니면 베이지톤이라 구매하기 쉽지가 않았는데 이 정도 색상이면 그레이톤이긴 하지만 화이트 코트에 가깝고 너무 밝지않아 부담없어 구매했어요.
# 길이가 생각보다 너무길어 종아리 중간까지 와서 편하게 입기는 힘들겠다 생각했고 더블이라 품은 큰데반해 소매는 넓지않아 두툼한 가디건 입으면 꽉껴요.
# 그래도 디자인 디테일이 좋고 원단이 탄탄하면서도 부드럽고 장점이 더 많은 코트.
# - 디자인은 사진그대로인데 입어보니 생각보다 무거워요..ㅠ 다른 롱코트랑 비교해봐도 무거워요ㅠ
# ==================================================
# 상품명: [W컨셉 단독][8th reorder] AIRY STRIPE SHIRT_2color
# URL: https://www.wconcept.co.kr/Product/307192326
# 리뷰:
# - 요즘 날씨에 휘뚜루마뚜루 입기 좋네요 ㅎㅎ
# - 상당히 박시하네요 흰색 하늘색 둘 다 봤을때 하늘색이 광택감이 살아있고 더 이쁘긴해요
# - 눈여겨보던 상품인데 세일해서 저렴하게 구매했어요
# 가벼운 재질이라 여름에 살안타템으로 최고일듯 합니다
# 색상도 밝아서 얼굴 환해지고 좋아요
# - 빠른 배송 좋은 상품 입니다 여름내내 잘 입을듯 합니다
# - 다들 칭찬일색인 이유가있네요
# 컬러가넘예쁘고 차르르하면서도 제법힘이느껴지는소재예요
# 화면보다 더이쁘네요
# 사이즈는 제가 생각한만큼 오버핏은아니예요~
# - 화면 그대로고 여름에 입기 좋아요
# ==================================================
# 상품명: 시그니처 도밍고워싱 와이드 데님
# URL: https://www.wconcept.co.kr/Product/307350088
# 리뷰:
# - 가격대비 퀄리티가 좋아요! 세일할때 잘산것같아요
# - 엄청 길지 않아서 저는 운동화 신으면 끌리지 않을 정도입니다 이런 핏은 자칫 뚱뚱해 보일 슈 있는데 다리 길어보이고 날씬해보이고 그냥 사세요
# - 청바지 두번째 구매인데 좋아요. 두께감도 길이도 핏도 좋고 배송도 빠르네요. 세일해서 가격도 넘 좋아요.
# - 굿 굿 굿이요
# - 옷은 맘에 드는데
# 저에겐 M사이즈가 크네요
# 가격도 착해서
# S사이즈 하나 더 주문해야겠어요
# ==================================================
# 상품명: The Moon Dress - Long(3color)
# URL: https://www.wconcept.co.kr/Product/304891098
# 리뷰:
# - 상체는 얇고 하체가 발달한 체형인데요,
# 허리는 23인치 힙 젤 높은부위가 38인치정도 나와요
# 재질자체가 유연해서 s사이즈 편하게 잘 맞았고요. 허리는
# 오히려 좀 남고 힙부위는 적당히 핏해서 부담스럽지 않아 딱 좋았어요.
#
# 저랑 같은 스펙에 완전 딱 맞게 입으시려면 xs 조금여유있게 입으시려면 s입으시면 될거같아요.
#
# 결혼식 이나 중요한 행사에 입으려고 구입했는데 재질도 트위드치고 까칠하지 않고 부드러운 편입니다. 마감이 전체적으로 고급스럽고 마음에 들어요.
#
# 단점은 어깨뽕이 생각보다 있다는점, 원피스 상의부분 연결이 실로 연결되있어서 괜찮을까 생각은 했는데, 큰 단점은 아닌거 같아요.
#
# 플로움 원피스는 처음인데 딱 제체형에 맞는
# 옷인거같아서 구입했는데 앞으로 자주 애용할거같네요! 👍🏻☺️ 고급스럽고 예뻐요.
# - 한여름에 입기엔 더운 소재에요! 트위드 재질로 고급져보이고 탄탄해보여요ㅎㅎ 배와 가슴부위가 조이긴한데 그만큼 날씬해보입니다 ㅎㅎ 플로움에서 2번째 구입인데 아주 만족스러워요~
# - 미듐으로 구입했는데 좀 여유있게 입고 싶어서 large로 교환했어요 navy 색상을 입어야 하는 자리인데 깔끔하게 잘 입을듯해요
# - 실물 너무 예쁘고 체형 딱 잡아줘서 좋아요 :)
# 입자마자 주변에서 제가 이제까지 입은 옷 중에 제일 예쁘다고 하네요 🤍 예쁜 옷 마니마니 만들어주세요
# - 너무너무 예뻐요 소재도 고급스럽고 라인도 예뻐요 결혼식이나 행사 등 참여옷으로 강추입니다!
# - 하객룩이나 상견례룩으로 최고! 곧 30이라 격식있는 자리가 종종 많아지는데 퀄리티도 좋고 고급스러워서 오래 입기 좋은 아이템인 것 같아요
# ==================================================
# 상품명: [캐시미어 30%] [Premium] Cashmere Hourglass Handmade Half Coat
# URL: https://www.wconcept.co.kr/Product/307059292
# 리뷰:
# - 생각보다
# 두꺼워요 잘맞아요
# ==================================================
# 상품명: [72H팝업] 렌 캐시미어 핸드메이드 코트_2colors
# URL: https://www.wconcept.co.kr/Product/301472489
# 리뷰:
# - 세일할때 싸게 샀어요
# - 소재도 좋고 넉넉하니 딱 기본이라 좋아요 세일할때사서 가격도 저렴하고 만족해요!
# - 오버사이즈로 딱 알맞게 이쁩니다!! 기본 롱코트로 추천
# - 처음 받았을 때 쉐입이 너어어어무 이뻐서 놀랬구요
# 입었을 때 몸에 착 감기는 느낌이 좋았어요!!
# 그냥 옷만 들었을 때는 생각보다 무거운가 했는데
# 입어보니 많이 무겁지 않았구요
# 어깨에서 팔 떨어지는 부분이 귀여웠어요ㅠㅠ
# 제가 작은 편은 아닌데,,,생각보다 되게 길더라구요
# 그래서 수선했다라는 얘기 많던데,,일단 겨울에 입어보고 생각하려구요!! 궁금란 점이 있었는데 친절하게 빨리 답변해주셔서 무지 좋았어요!! 세일로 만나서 잘 입을
# 것 같네요!!
# 한가지!! 여기는 옷의 디테일 부분에서 약간 머뭇거리게 되는 부분이 있는데,,그걸 뛰어넘을 정도로 옷이 이쁘네요!! 참고하세요><
# - 세일해서 저렴하게 잘 산 것 같아요! 양쪽 손목에 달린 단추가 짝짝이 인 게 아주 귀엽네요ㅎㅎㅎ 무거울까봐 걱정했는데 가볍고 따수워요.
# - 옷 예쁘고 적당히 무게감있고 고급스러워요.
# 근데 허리끈 고정하는걸 왜이렇게 허술하게 만들었을까요..?????? 달랑 실 몇가닥짜리로 허리끈을 버티려니 세번정도 입고다니니까 양쪽 다 떨어지덥니다.. 사진에서처럼 떨어진채로 그냥 묶고다니는중입니다.
# ==================================================
# 상품명: Twist Breeze Blouse [White]
# URL: https://www.wconcept.co.kr/Product/306848623
# 리뷰:
# - 화면과 같고 예뻐요
# 소재도 시원해보이긴 하는데
# 입으면 잘 모르겠지만..
# 옷 예쁘다는 소리 많이 들었어요
# - 바스락거리는 소재여서 덥지 않고 사이즈도 적당합니다. 주름이 많이 지는 소재일까 걱정했는데 그 자체로 자연스럽고 깔끔합니다. 너무 예뻐요!!!
# - 이뻐요 편하구요
# - 가슴 꼬임 디테일이 포인트고
# 어깨부분도 너무 예쁘고
# 잘만든 옷같아요ㅋㄱㄴ
# 다만 얇아서 비쳐서 나시입어줘야합니다.
# - 소개팅 무적템입니다...! 완전 잘샀닥
# - 고민은 배송만 늦출뿐. 어느 바지에도 잘 어울려서 너무 만족 합니다.. 🥹👍🏻 앞에 있는 트임이 흔하지 않아서 좋아요! 고민 하시는 분들 당장 주문하세요 넥 라인도 존예
# ==================================================
# 상품명: NJ3LR32L 화이트라벨 여성 에어로런 자켓_LIGHT BLUE
# URL: https://www.wconcept.co.kr/Product/306769137
# 리뷰:
# - 여름 러닝에 딱 좋구요! 가을 등산때도 들고가려구요!
# - 친구 선물로 줬어요~ 만족스러워요
# - 색상이 넘 예뻐욤ㅎ^^ 가볍고 디자인 깔끔하고 청량감에 바캉스 가고싶네욤ㅋ^^
# - 컬러 미쳤네요. 파스텔톤이라 더 고급짐.
# 가벼워서 장마철이나 초가을까지 착용할 수 있을거 같아요.
# 옆라인이 매쉬라 운동시에도 좋을듯👍
# - 좋습니다. 아주 맘에 들어요
# - 팔이 엄청 기네요 그외엔 가볍고 얇고 여름용으로 딱입니다
# ==================================================
# 상품명: [퀸지PICK] [컬러추가]V-neck Cardigan & Sleeveless Top Set_7color
# URL: https://www.wconcept.co.kr/Product/306690200
# 리뷰:
# - 컬러 고민하다 두개다 구매했습니다.
# - 왜 나시가 손바닥 만하다고 하는지 알겠네요.컬러는 예뻐요
# - 뭔가 그물같은 재질이라 늘어날것같아서 조심히 입개될거같애요 좀 짧긴한데 치마 바지에 무난히 입을수 잇을정도에요
# - 비비드한 색감에 반해서 구매했습니다
# 소재 탄탄하고 시권하고 좋어요!!!
# - 한여름엔 좀 더울거 같아요 간절기에 입으면 깔끔할거 같아요 소재가 힘이 있어서 고급져 보이고 마감도 좋아요 예쁘게 입어 볼께요
# - 얇아서 여름에 입기도 좋고
# 피부에 닿는 촉감도 좋아요
# 핏도 예쁘고 대만족입니다
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[32], line 22
#      20 url = item["URL"]
#      21 driver.get(f"{url}#review")
# ---> 22 time.sleep(1)
#      24 reviews = driver.find_elements(By.CSS_SELECTOR, "p.pdt_review_text")
#      25 product_reviews = []
#
# KeyboardInterrupt:

# %%
from openpyxl import Workbook

wb = Workbook()

ws_top100 = wb.active
ws_top100.title = "상위100상품"

ws_top100.append(["카테고리","상품명","URL","리뷰 수","평균평점"])
for idx,row in df_top100.iterrows():
    ws_top100.append([row["카테고리"],row["상품명"],row["URL"],row["리뷰 수"],row["평균평점"]])

ws_category=wb.create_sheet(title = "카테고리별 통계") 

ws_category.append(["카테고리","총 리뷰수","평균평점"])
for idx, row in category_summary.iterrows():
    ws_category.append([
        row["카테고리"],row["리뷰 수"],round(row["평균평점"],2)
    ])

filename = "wconcept_result.xlsx"
wb.save(filename)
print(f"1개의 엑셀파일에 시트2개 저장 완료 : {filename}")
# Out:
# 1개의 엑셀파일에 시트2개 저장 완료 : wconcept_result.xlsx

# %%
import pandas as pd 
import pymysql
from sqlalchemy import create_engine, text

DB_NAME = "Wconcept_db_v1"
TABLE_TOP100 = "top100_products"
TABLE_CATEGORY = "category_summary"
USER = "root"
PASSWORD = "hithere4961"
HOST = "localhost"
PORT = 3306

xlsx_path = "wconcept_result.xlsx"
SHEET_TOP100 = "상위100상품"
SHEET_CATEGORY = "카테고리별 통계"

df_top100 = pd.read_excel(xlsx_path, sheet_name = SHEET_TOP100)
df_category = pd.read_excel(xlsx_path, sheet_name = SHEET_CATEGORY)

top100_cols = {
    "카테고리": "category",
    "상품명": "product_name",
    "URL": "url",
    "리뷰 수": "review_count",
    "평균평점": "avg_rating",
}

category_cols = {
    "카테고리": "category",
    "총 리뷰수": "total_review_count",
    "평균평점": "avg_rating",
}

df_top100 = df_top100.rename(columns=top100_cols)[list(top100_cols.values())]
df_category = df_category.rename(columns=category_cols)[list(category_cols.values())]

df_top100 = df_top100.dropna(subset=["category","product_name","review_count","avg_rating"])
df_category = df_category.dropna(subset=["category","total_review_count","avg_rating"])

df_top100["review_count"] = df_top100["review_count"].astype(int)
df_top100["avg_rating"] = df_top100["avg_rating"].astype(float).round(2)

df_category["total_review_count"] = df_category["total_review_count"].astype(int)
df_category["avg_rating"] = df_category["avg_rating"].astype(float).round(2)


conn_admin = pymysql.connect(host=HOST,user=USER,password=PASSWORD,port=PORT, autocommit=True)

with conn_admin.cursor() as cur :
    cur.execute(f"CREATE DATABASE IF NOT EXISTS `{DB_NAME}` CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;")
conn_admin.close()

engine = create_engine(
    f"mysql+pymysql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB_NAME}?charset=utf8mb4"
)

ddl_top100 = f"""
CREATE TABLE IF NOT EXISTS `{TABLE_TOP100}` (
    `id` BIGINT UNSIGNED NOT NULL PRIMARY KEY AUTO_INCREMENT,
    `category` VARCHAR(50) NOT NULL,
    `product_name` VARCHAR(255) NOT NULL,
    `url` TEXT NULL , 
    `review_count` INT NOT NULL,
    `avg_rating` DECIMAL(3,2) NOT NULL,
    `created_at` TIMESTAMP NOT NULL DEFAULT CURRENT_TIMESTAMP
)
"""


ddl_category = f"""
CREATE TABLE IF NOT EXISTS `{TABLE_CATEGORY}` (
    `id` INT UNSIGNED NOT NULL PRIMARY KEY AUTO_INCREMENT,
    `category` VARCHAR(50) NOT NULL,
    `total_review_count` INT NOT NULL,
    `avg_rating` DECIMAL(3,2) NOT NULL,
    `created_at` TIMESTAMP NOT NULL DEFAULT CURRENT_TIMESTAMP
)
"""

with engine.begin() as conn : 
    conn.execute(text(ddl_top100))
    conn.execute(text(ddl_category))

with engine.begin() as conn : 
    df_top100[["category","product_name","url","review_count","avg_rating"]].to_sql(
        TABLE_TOP100, con=conn,if_exists="append",index=False
    )
    df_category[["category","total_review_count","avg_rating"]].to_sql(
        TABLE_CATEGORY, con=conn,if_exists="append",index=False
    )

def ensure_index(conn,schema,table,index_name,column_list) :
    q = text(""" 
        SELECT 1 
        FROM information_schema.statistics
        WHERE table_schema = :schema AND 
        table_name=:table AND
        index_name=:index_name
    """)
    exists = conn.execute(q,{"schema":schema,"table":table,"index_name":index_name}).fetchone()
    

with engine.begin() as conn :
    ensure_index(conn, DB_NAME, TABLE_TOP100,f"idx_{TABLE_TOP100}_category",["category"])
    ensure_index(conn, DB_NAME, TABLE_TOP100,f"idx_{TABLE_TOP100}_review_count",["review_count"])
    ensure_index(conn, DB_NAME, TABLE_TOP100,f"idx_{TABLE_TOP100}_avg_rating",["avg_rating"])
    ensure_index(conn, DB_NAME, TABLE_CATEGORY,f"idx_{TABLE_CATEGORY}_total_review",["total_review_count"])
    ensure_index(conn, DB_NAME, TABLE_CATEGORY,f"idx_{TABLE_CATEGORY}_avg_rating",["avg_rating"])

print("MySQL 데이터 생성 완료")
# Out:
# MySQL 데이터 생성 완료

# %%
import hashlib
from sqlalchemy import text

PRODUCT_TABLE = "top100_products"
REVIEWS_TABLE = "reviews"

def _md5(product_id: int, s: str) -> str:
    return hashlib.md5(f"{product_id}|{s}".encode("utf-8")).hexdigest()

def _normalize(txt: str) -> str:
    # 공백/개행 정리(선택)
    return " ".join(txt.split()).strip()

# URL -> product_id 매핑 (이미 products를 채워두셨으므로 URL로 찾는게 가장 확실)
with engine.begin() as conn:
    # URL이 TEXT여도 where 조건으로 조회는 문제없음
    sql_get_id = text(f"SELECT id, category, product_name FROM {PRODUCT_TABLE} WHERE url = :url LIMIT 1")

    ins_sql = text(f"""
        INSERT IGNORE INTO {REVIEWS_TABLE}
            (product_id, review_text, review_md5, product_name, category)
        VALUES
            (:product_id, :review_text, :review_md5, :product_name, :category)
    """)

    for item in all_data:
        url = item.get("URL")
        if not url:
            continue

        row = conn.execute(sql_get_id, {"url": url}).fetchone()
        if not row:
            # 필요한 경우: 제품 테이블에 없다면 먼저 upsert 하도록 변경 가능
            print(f"[SKIP] products에 없음: {url}")
            continue

        pid, category, pname = int(row[0]), row[1], row[2]

        for raw in item.get("리뷰", []):
            txt = _normalize(raw)
            if not txt:
                continue
            conn.execute(ins_sql, {
                "product_id": pid,
                "review_text": txt,
                "review_md5": _md5(pid, txt),
                "product_name": pname,   # 옵션(편의 저장)
                "category": category     # 옵션(편의 저장)
            })

print("✅ 리뷰 삽입 완료")
# Out:
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306038291
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307350085
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306038292
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307335695
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307350064
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306141668
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307363913
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306788003
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301864566
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307350088
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/304891098
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307059292
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301472489
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306769137
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306042608
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307381191
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307350112
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307269221
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307377173
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307375882
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306567458
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306879339
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307360523
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302266402
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306873884
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307173338
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306822419
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306937536
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306931367
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/304360208
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307268555
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305783381
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306028892
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306389068
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307319127
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306820963
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306873494
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306773433
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/304350708
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306017014
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305840093
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305716516
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306656362
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306061260
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306642433
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306910282
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305850671
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306739533
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306896537
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307191229
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306816700
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306104102
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307329571
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305795831
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307181407
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306388824
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307358057
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301864556
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306075506
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307376391
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306094074
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306387767
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306871707
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306959193
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307363771
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306650854
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/303177652
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306035870
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306908309
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307349636
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306996352
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306182759
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307349640
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306683429
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305068885
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306819868
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306881816
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307363824
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306832886
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306683013
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306046510
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306714097
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306832838
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307349625
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302754567
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306957459
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306569026
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/300785999
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306586654
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305832018
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306833952
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305174527
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306989867
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/303423992
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305765120
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307363826
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306611652
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306744053
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306175498
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306593253
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306003846
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305260658
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307359833
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307317064
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301582414
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305909191
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/303431232
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307383134
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306841127
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305694047
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306874162
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306989869
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302299692
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302617513
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306029911
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306776828
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302297860
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306707331
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301601361
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301797689
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307264814
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306012078
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306913031
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305894199
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306611029
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306964915
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306085416
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306586666
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/303940319
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305924012
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307285308
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301822724
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307376495
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307359535
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305924607
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302432235
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306980044
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306794482
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306885828
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306623875
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306695296
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306796125
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306274946
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306163807
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306115583
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306634506
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305685774
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306933626
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306679341
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306066940
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306048744
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306884445
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305778551
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307365139
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305846155
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307003751
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307297246
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307346664
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305982308
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307331629
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307316941
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307015793
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/303603616
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307356992
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307365468
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307319818
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307281998
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305736478
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306609198
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306363429
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305736518
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301073530
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307297248
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306545588
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305121894
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306359546
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306090270
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306858677
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301419234
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306815887
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306570039
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301639306
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306654028
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306025023
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/303668078
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307003745
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305864959
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306546144
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/303436112
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306012304
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306170281
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305885101
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/304572353
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307274957
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306877164
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306599698
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306599611
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307242446
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301337734
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306639832
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307357015
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302741376
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305806428
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306763956
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/303470889
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305288032
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306767833
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305811777
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307178430
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301684026
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306563748
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306719745
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306722709
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307242573
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306719657
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306840247
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305065765
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306848001
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306679343
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307364211
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306379969
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306788197
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307241735
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306875788
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301721307
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306644023
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/304558838
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306644030
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305852802
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/303227814
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302938308
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305822112
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306946457
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306537396
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307257071
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302228877
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305743751
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/300656494
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306544960
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305910959
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301737711
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301757457
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306312263
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306544555
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306641564
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301577443
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/303099469
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305695345
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306864958
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307385634
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306087963
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306716038
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306697612
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/300885226
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306880331
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306686168
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302306130
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306644024
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306946367
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306659323
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305873361
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307257947
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305861079
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307376246
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305823694
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306849129
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305734919
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306149993
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306988068
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305762035
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307360367
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307360381
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307360321
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306611585
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305044862
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305911098
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307318425
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305888560
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302325601
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307158276
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306120443
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302325794
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307259004
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302918466
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301683335
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305915124
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/300910363
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301881365
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305910753
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302766540
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305758976
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307317129
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301848631
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/303770564
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306660470
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306967587
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306164494
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306832661
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/300511984
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306259220
# ✅ 리뷰 삽입 완료

# %%
import re, hashlib
from urllib.parse import urlparse, parse_qsl, urlencode, urlunparse
from sqlalchemy import text

PRODUCT_TABLE = "top100_products"
REVIEWS_TABLE  = "reviews"

def normalize_url(u: str) -> str:
    if not u: return u
    u = u.strip()
    # 1) 해시(#...) 제거
    u = u.split('#', 1)[0]
    # 2) 공백/개행 제거
    u = " ".join(u.split())
    # 3) 쿼리 파라미터 정렬(순서 달라져도 동일 취급)
    try:
        p = urlparse(u)
        q = sorted(parse_qsl(p.query, keep_blank_values=True))
        new_query = urlencode(q)
        # 4) 도메인 소문자
        netloc = p.netloc.lower()
        # 5) 끝 슬래시 정규화(원하면 제거)
        path = re.sub(r'//+', '/', p.path or '')
        # 재조합
        u = urlunparse((p.scheme, netloc, path, '', new_query, ''))
        # 끝 슬래시 제거(선택): 사이트 규칙에 맞게 결정
        if u.endswith('/'):
            u = u[:-1]
    except Exception:
        pass
    return u

with engine.begin() as conn:
    sql_exact = text(f"""
        SELECT id, category, product_name, url
        FROM {PRODUCT_TABLE}
        WHERE url = :url
        LIMIT 1
    """)
    sql_exact_norm = text(f"""
        SELECT id, category, product_name, url
        FROM {PRODUCT_TABLE}
        WHERE REPLACE(SUBSTRING_INDEX(url, '#', 1), ' ', '') = :norm     -- 해시/공백 제거 일치
        LIMIT 1
    """)
    sql_like = text(f"""
        SELECT id, category, product_name, url
        FROM {PRODUCT_TABLE}
        WHERE url LIKE :prefix
        ORDER BY LENGTH(url) DESC
        LIMIT 1
    """)
    sql_by_name = text(f"""
        SELECT id, category, product_name, url
        FROM {PRODUCT_TABLE}
        WHERE product_name = :name
        LIMIT 1
    """)

    ins_review = text(f"""
        INSERT IGNORE INTO {REVIEWS_TABLE}
            (product_id, review_text, review_md5, product_name, category)
        VALUES
            (:product_id, :review_text, :review_md5, :product_name, :category)
    """)

    miss = 0
    for item in all_data:
        raw = (item.get("URL") or "").strip()
        if not raw:
            continue

        norm = normalize_url(raw)

        row = conn.execute(sql_exact, {"url": raw}).fetchone()
        if not row:
            row = conn.execute(sql_exact_norm, {"norm": normalize_url(raw)}).fetchone()
        if not row:
            # 도메인+경로까지만 LIKE로 폴백
            # 예) https://site.com/p/123?x=1 → https://site.com/p/123%
            parsed = urlparse(norm)
            prefix = urlunparse((parsed.scheme, parsed.netloc, parsed.path, '', '', ''))
            if prefix.endswith('/'): prefix = prefix[:-1]
            row = conn.execute(sql_like, {"prefix": prefix + '%'}).fetchone()
        if not row:
            # 최후 폴백: 상품명 일치
            row = conn.execute(sql_by_name, {"name": item.get("상품명")}).fetchone()

        if not row:
            miss += 1
            print(f"[SKIP] products에 없음: {raw}  → norm={norm}")
            continue

        pid, category, pname, db_url = int(row[0]), row[1], row[2], row[3]

        for t in item.get("리뷰", []):
            t = " ".join(t.split()).strip()
            if not t: 
                continue
            md5key = hashlib.md5(f"{pid}|{t}".encode("utf-8")).hexdigest()
            conn.execute(ins_review, {
                "product_id": pid,
                "review_text": t,
                "review_md5": md5key,
                "product_name": pname,
                "category": category
            })

    print("완료. 매칭 실패 건수:", miss)
# Out:
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306038291  → norm=https://www.wconcept.co.kr/Product/306038291
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307350085  → norm=https://www.wconcept.co.kr/Product/307350085
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306038292  → norm=https://www.wconcept.co.kr/Product/306038292
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307335695  → norm=https://www.wconcept.co.kr/Product/307335695
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307350064  → norm=https://www.wconcept.co.kr/Product/307350064
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306141668  → norm=https://www.wconcept.co.kr/Product/306141668
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307363913  → norm=https://www.wconcept.co.kr/Product/307363913
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306788003  → norm=https://www.wconcept.co.kr/Product/306788003
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301864566  → norm=https://www.wconcept.co.kr/Product/301864566
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307350088  → norm=https://www.wconcept.co.kr/Product/307350088
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/304891098  → norm=https://www.wconcept.co.kr/Product/304891098
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307059292  → norm=https://www.wconcept.co.kr/Product/307059292
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301472489  → norm=https://www.wconcept.co.kr/Product/301472489
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306769137  → norm=https://www.wconcept.co.kr/Product/306769137
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306042608  → norm=https://www.wconcept.co.kr/Product/306042608
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307381191  → norm=https://www.wconcept.co.kr/Product/307381191
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307350112  → norm=https://www.wconcept.co.kr/Product/307350112
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307269221  → norm=https://www.wconcept.co.kr/Product/307269221
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307377173  → norm=https://www.wconcept.co.kr/Product/307377173
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307375882  → norm=https://www.wconcept.co.kr/Product/307375882
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306567458  → norm=https://www.wconcept.co.kr/Product/306567458
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307318425  → norm=https://www.wconcept.co.kr/Product/307318425
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305888560  → norm=https://www.wconcept.co.kr/Product/305888560
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302325601  → norm=https://www.wconcept.co.kr/Product/302325601
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307158276  → norm=https://www.wconcept.co.kr/Product/307158276
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306120443  → norm=https://www.wconcept.co.kr/Product/306120443
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302325794  → norm=https://www.wconcept.co.kr/Product/302325794
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307259004  → norm=https://www.wconcept.co.kr/Product/307259004
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302918466  → norm=https://www.wconcept.co.kr/Product/302918466
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301683335  → norm=https://www.wconcept.co.kr/Product/301683335
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305915124  → norm=https://www.wconcept.co.kr/Product/305915124
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/300910363  → norm=https://www.wconcept.co.kr/Product/300910363
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301881365  → norm=https://www.wconcept.co.kr/Product/301881365
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305910753  → norm=https://www.wconcept.co.kr/Product/305910753
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/302766540  → norm=https://www.wconcept.co.kr/Product/302766540
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/305758976  → norm=https://www.wconcept.co.kr/Product/305758976
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/307317129  → norm=https://www.wconcept.co.kr/Product/307317129
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/301848631  → norm=https://www.wconcept.co.kr/Product/301848631
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/303770564  → norm=https://www.wconcept.co.kr/Product/303770564
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306660470  → norm=https://www.wconcept.co.kr/Product/306660470
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306967587  → norm=https://www.wconcept.co.kr/Product/306967587
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306164494  → norm=https://www.wconcept.co.kr/Product/306164494
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306832661  → norm=https://www.wconcept.co.kr/Product/306832661
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/300511984  → norm=https://www.wconcept.co.kr/Product/300511984
# [SKIP] products에 없음: https://www.wconcept.co.kr/Product/306259220  → norm=https://www.wconcept.co.kr/Product/306259220
# 완료. 매칭 실패 건수: 300

# %%
import re, hashlib
from sqlalchemy import text

def extract_code(u: str):
    m = re.search(r'(\d+)$', u or '')
    return int(m.group(1)) if m else None

sql_by_code = text("""
    SELECT id, category, product_name FROM top100_products
    WHERE product_code = :code
    LIMIT 1
""")

ins_review = text("""
    INSERT IGNORE INTO reviews
      (product_id, review_text, review_md5, product_name, category)
    VALUES
      (:product_id, :review_text, :review_md5, :product_name, :category)
""")

with engine.begin() as conn:
    miss = 0
    for item in all_data:
        code = extract_code(item.get("URL"))
        if not code:
            print("[SKIP] 코드 추출 실패:", item.get("URL"))
            miss += 1
            continue

        row = conn.execute(sql_by_code, {"code": code}).fetchone()
        if not row:
            print("[SKIP] products에 코드 없음:", code)
            miss += 1
            continue

        pid, category, pname = int(row[0]), row[1], row[2]

        for t in item.get("리뷰", []):
            t = " ".join(t.split()).strip()
            if not t: 
                continue
            md5key = hashlib.md5(f"{pid}|{t}".encode("utf-8")).hexdigest()
            conn.execute(ins_review, {
                "product_id": pid,
                "review_text": t,
                "review_md5": md5key,
                "product_name": pname,
                "category": category
            })

    print("완료. 매칭 실패 건수:", miss)
# Out:
# [SKIP] products에 코드 없음: 306038291
# [SKIP] products에 코드 없음: 307350085
# [SKIP] products에 코드 없음: 306038292
# [SKIP] products에 코드 없음: 307335695
# [SKIP] products에 코드 없음: 307350064
# [SKIP] products에 코드 없음: 306141668
# [SKIP] products에 코드 없음: 307363913
# [SKIP] products에 코드 없음: 306788003
# [SKIP] products에 코드 없음: 301864566
# [SKIP] products에 코드 없음: 305852802
# [SKIP] products에 코드 없음: 303227814
# [SKIP] products에 코드 없음: 302938308
# [SKIP] products에 코드 없음: 305822112
# [SKIP] products에 코드 없음: 306946457
# [SKIP] products에 코드 없음: 306537396
# [SKIP] products에 코드 없음: 307257071
# [SKIP] products에 코드 없음: 302228877
# [SKIP] products에 코드 없음: 305743751
# [SKIP] products에 코드 없음: 300656494
# [SKIP] products에 코드 없음: 306544960
# [SKIP] products에 코드 없음: 305910959
# [SKIP] products에 코드 없음: 301737711
# [SKIP] products에 코드 없음: 301757457
# [SKIP] products에 코드 없음: 306312263
# [SKIP] products에 코드 없음: 306544555
# [SKIP] products에 코드 없음: 306641564
# [SKIP] products에 코드 없음: 301577443
# [SKIP] products에 코드 없음: 303099469
# [SKIP] products에 코드 없음: 305695345
# [SKIP] products에 코드 없음: 306864958
# [SKIP] products에 코드 없음: 307385634
# [SKIP] products에 코드 없음: 306087963
# [SKIP] products에 코드 없음: 306716038
# [SKIP] products에 코드 없음: 306697612
# [SKIP] products에 코드 없음: 300885226
# [SKIP] products에 코드 없음: 306880331
# [SKIP] products에 코드 없음: 306686168
# [SKIP] products에 코드 없음: 302306130
# [SKIP] products에 코드 없음: 306644024
# [SKIP] products에 코드 없음: 306946367
# [SKIP] products에 코드 없음: 306659323
# [SKIP] products에 코드 없음: 305873361
# [SKIP] products에 코드 없음: 307257947
# [SKIP] products에 코드 없음: 305861079
# [SKIP] products에 코드 없음: 307376246
# [SKIP] products에 코드 없음: 305823694
# [SKIP] products에 코드 없음: 306849129
# [SKIP] products에 코드 없음: 305734919
# [SKIP] products에 코드 없음: 306149993
# [SKIP] products에 코드 없음: 306988068
# [SKIP] products에 코드 없음: 305762035
# [SKIP] products에 코드 없음: 307360367
# [SKIP] products에 코드 없음: 307360381
# [SKIP] products에 코드 없음: 307360321
# [SKIP] products에 코드 없음: 306611585
# [SKIP] products에 코드 없음: 305044862
# [SKIP] products에 코드 없음: 305911098
# [SKIP] products에 코드 없음: 307318425
# [SKIP] products에 코드 없음: 305888560
# [SKIP] products에 코드 없음: 302325601
# [SKIP] products에 코드 없음: 307158276
# [SKIP] products에 코드 없음: 306120443
# [SKIP] products에 코드 없음: 302325794
# [SKIP] products에 코드 없음: 307259004
# [SKIP] products에 코드 없음: 302918466
# [SKIP] products에 코드 없음: 301683335
# [SKIP] products에 코드 없음: 305915124
# [SKIP] products에 코드 없음: 300910363
# [SKIP] products에 코드 없음: 301881365
# [SKIP] products에 코드 없음: 305910753
# [SKIP] products에 코드 없음: 302766540
# [SKIP] products에 코드 없음: 305758976
# [SKIP] products에 코드 없음: 307317129
# [SKIP] products에 코드 없음: 301848631
# [SKIP] products에 코드 없음: 303770564
# [SKIP] products에 코드 없음: 306660470
# [SKIP] products에 코드 없음: 306967587
# [SKIP] products에 코드 없음: 306164494
# [SKIP] products에 코드 없음: 306832661
# [SKIP] products에 코드 없음: 300511984
# [SKIP] products에 코드 없음: 306259220
# 완료. 매칭 실패 건수: 300
