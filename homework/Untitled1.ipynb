# %%
import requests 
from bs4 import BeautifulSoup as bs 

url = "https://m.bunjang.co.kr/search/products?q=%ED%82%A4%EB%B3%B4%EB%93%9C"
res = requests.get(url)
soup = bs(res.content , "html.parser")
data = soup.select(".sc-kasBVs")
data
# Out:
# []
