# %%
# 보다 세부적으로 EDA 를 활용해서 데이터를 확인 및 검증하기 위한 방법론 
# Feature = column  상관관계 분석
# 데이터 사이언티스트 , 데이터 분석가 -> 데이터 내 feature 간 상관관계를 누가 더 세부적으로 심도있게 분석하는가 
# heatmap
# scatter 

#상관관계를 체크 및 확인하기 위해서 상관계수 사용 
# 상관계수 : 1 에 수렴할수록 상관관계가 강하다
