# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: pandas in c:\programdata\anaconda3\lib\site-packages (2.2.3)
# Requirement already satisfied: numpy>=1.26.0 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.1.3)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\programdata\anaconda3\lib\site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in c:\programdata\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 
import pandas as pd 
import re 

service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("start-maximized")
driver=webdriver.Chrome(service=service, options=options)

url = "https://www.musinsa.com/main/musinsa/recommend?gf=A" 
driver.get(url)
time.sleep(2)

search_button = driver.find_element(By.XPATH, "//button[@class='sc-dzagxs-2 HinGG gtm-click-button']")
search_button.click()
time.sleep(2)

popular_keywords = driver.find_elements(By.CSS_SELECTOR, ".search-home-popular-wrap .sc-1xzm8bl-1")
target_keyword = popular_keywords[2].text
# print(target_keyword)

search_input = driver.find_element(By.XPATH, "//input[@placeholder='검색어를 입력하세요']")
search_input.clear()
search_input.send_keys(f"{target_keyword}")  
time.sleep(1)
search_input.send_keys(Keys.ENTER)
scroll_pause = 1

for i in range(10):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(scroll_pause)

products = driver.find_elements(By.CSS_SELECTOR, "div.sc-d36st-1.elXjMR")[:100]
product_data = []

for product in products :
    try : 
        name = product.find_element(By.CSS_SELECTOR, "div.sc-cMuefe.jIlLeV a.gtm-select-item span").text.strip()
        url = product.find_element(By.CSS_SELECTOR, "div.sc-cMuefe.jIlLeV a.gtm-select-item").get_attribute("href")
        review_info = product.find_elements(By.CSS_SELECTOR, "span.text-etc_11px_reg.text-yellow.font-pretendard")[1].text
        review_count = int(re.sub(r'[^\d]',"", review_info)) if review_info else 0
        product_data.append({"상품명": name, "URL":url , "리뷰 수" : review_count })
    except : 
        continue

df = pd.DataFrame(product_data)
df_top30 = df.sort_values(by="리뷰 수",ascending=False).head(30).reset_index(drop=True)


time.sleep(2)
driver.quit()

df_top30.head(30)
# Out:
#                                              상품명  \
# 0             Retro Motorcycle Graphic Tee White
# 1                            UNICORN CROP TEE BK
# 2                 오버핏 크루넥 메탈릭 크롬 하트 로고 반팔 티셔츠 블랙
# 3                        Identity T Shirt - Blue
# 4                  460G 다트 헤비 머드 다잉 티셔츠-더스키 버건디-
# 5              [4color] Daily Supima Logo Half T
# 6                            [3PACK] 테크니컬 쿨링 티셔츠
# 7                    럭비 카라 래글런 트랙 타슬란 반팔티 GT-377
# 8                              HUH!! TEE [WHITE]
# 9               Heart Patch Cotton T-shirt White
# 10                      세미크롭 링거 파리 반팔 티셔츠 GT-357
# 11                       OHP X MOAI b캠핑 세미오버 반팔티
# 12             2PACK COOL TEE_WHITE(IK2DMMT505A)
# 13                   [PAT&MAT] 베스트 프렌드 티셔츠 - 화이트
# 14              WOMEN 크롭 플리츠 비엔나 플레어 반팔티 [BLACK]
# 15               [쿨탠다드] 우먼즈 짐 액티브 숏 슬리브 (2color)
# 16                    백 포인트 스튜디오 오버핏 반팔 티_5COLOR
# 17                   ODSD 스트라이프 레귤러핏 티셔츠 - IVORY
# 18  Love Leopard Graphic T-shirt VW5ME607_3color
# 19              [반팔ver]나그랑뒷반팔티셔츠(PBE03S-WHTW004)
# 20                         심볼 로고 피그먼트 티셔츠-4Color
# 21                WEB LOGO T-SHIRTS [WHITE/CAMO]
# 22                      Starlight T-shirts Brown
# 23                             가먼트 다잉 숏 슬리브 [차콜]
# 24                  VSW Cartoon 2 T-Shirts White
# 25                        98 캘리포니아 래글런 반팔 티셔츠-크림
# 26                     에센셜 베이직 이너티셔츠 3팩 (WH2/BK)
# 27                          시그니처 오버핏 반팔티 2colors
# 28        [Mmlg] STAMP COLLECTOR HF-T (ASH GREY)
# 29                    시트론 썸머 그래픽 반팔 티셔츠 세터데이 화이트
#
#                                          URL  리뷰 수
# 0   https://www.musinsa.com/products/4241149   909
# 1   https://www.musinsa.com/products/3187402   769
# 2   https://www.musinsa.com/products/4126676   508
# 3   https://www.musinsa.com/products/3021847   483
# 4   https://www.musinsa.com/products/4146751   341
# 5   https://www.musinsa.com/products/4141467   312
# 6   https://www.musinsa.com/products/4217237   294
# 7   https://www.musinsa.com/products/4953179   265
# 8   https://www.musinsa.com/products/4113186   241
# 9   https://www.musinsa.com/products/5040946   216
# 10  https://www.musinsa.com/products/4116796   212
# 11  https://www.musinsa.com/products/2450848   193
# 12  https://www.musinsa.com/products/3099535   183
# 13  https://www.musinsa.com/products/3860375   159
# 14  https://www.musinsa.com/products/3260958   150
# 15  https://www.musinsa.com/products/3535312   120
# 16  https://www.musinsa.com/products/4964024   105
# 17  https://www.musinsa.com/products/4897558    95
# 18  https://www.musinsa.com/products/4982336    84
# 19  https://www.musinsa.com/products/4943233    80
# 20  https://www.musinsa.com/products/3995530    73
# 21  https://www.musinsa.com/products/4972779    73
# 22  https://www.musinsa.com/products/5077963    67
# 23  https://www.musinsa.com/products/4053108    65
# 24  https://www.musinsa.com/products/3224048    64
# 25  https://www.musinsa.com/products/5024221    59
# 26  https://www.musinsa.com/products/4145375    58
# 27  https://www.musinsa.com/products/4430645    56
# 28  https://www.musinsa.com/products/4943587    54
# 29  https://www.musinsa.com/products/4074730    52

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time 
import pandas as pd 
import re 

service = Service(ChromeDriverManager().install())
options = Options()

# options.add_argument("--headless")
# options.add_argument("--disable-gpu")
options.add_argument("--user-agent=Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/138.0.0.0 Safari/537.36")
options.add_argument("--lang=ko_KR")
options.add_argument("--disable-dev-shm-usage")
options.add_argument("start-maximized")
driver=webdriver.Chrome(service=service, options=options)

url = "https://www.musinsa.com/main/musinsa/recommend?gf=A" 
driver.get(url)
time.sleep(2)

search_button = driver.find_element(By.XPATH, "//button[@class='sc-dzagxs-2 HinGG gtm-click-button']")
search_button.click()
time.sleep(2)

popular_keywords = driver.find_elements(By.CSS_SELECTOR, ".search-home-popular-wrap .sc-1xzm8bl-1")
target_keyword = popular_keywords[2].text
# print(target_keyword)

search_input = driver.find_element(By.XPATH, "//input[@placeholder='검색어를 입력하세요']")
search_input.clear()
search_input.send_keys(f"{target_keyword}")  
time.sleep(1)
search_input.send_keys(Keys.ENTER)
scroll_pause = 1

for i in range(10):
    driver.execute_script("window.scrollTo(0, document.body.scrollHeight);")
    time.sleep(scroll_pause)

products = driver.find_elements(By.CSS_SELECTOR, "div.sc-d36st-1.elXjMR")[:100]
product_data = []

for product in products :
    try : 
        name = product.find_element(By.CSS_SELECTOR, "div.sc-cMuefe.jIlLeV a.gtm-select-item span").text.strip()
        url = product.find_element(By.CSS_SELECTOR, "div.sc-cMuefe.jIlLeV a.gtm-select-item").get_attribute("href")
        review_info = product.find_elements(By.CSS_SELECTOR, "span.text-etc_11px_reg.text-yellow.font-pretendard")[1].text
        review_count = int(re.sub(r'[^\d]',"", review_info)) if review_info else 0
        product_data.append({"상품명": name, "URL":url , "리뷰 수" : review_count })
    except : 
        continue

df = pd.DataFrame(product_data)
df_top30 = df.sort_values(by="리뷰 수",ascending=False).head(30).reset_index(drop=True)


time.sleep(2)
driver.quit()

df_top30.head(30)

# %%
from openpyxl import Workbook

driver = webdriver.Chrome(service = service , options = options)
all_reviews = []

for idx,row in df_top30.iterrows() : 
    print(f"{idx + 1}번째 상품리뷰 수집 중 :" , {row['상품명']})
    driver.get(row['URL'])
    time.sleep(2)

    try : 
        review_tab = driver.find_element(By.XPATH , "//*[@id='root']/div[1]/div[1]/div[2]/div/button[4]")
        review_tab.click()
        time.sleep(1)
        for i in range(3):
            driver.execute_script("window.scrollTo(0,document.body.scrollHeight);")
            time.sleep(1.5)

        review_elements = driver.find_elements(By.CSS_SELECTOR, "span.text-body_13px_reg.text-black.font-pretendard")
        for review in review_elements[:10] :
            text = review.text.strip()
            if text : 
                all_reviews.append({
                    "상품명" : row["상품명"], 
                    "리뷰" : text
                })
    except Exception as e : 
        print("리뷰 수집 실패" , e)
        continue 

driver.quit()

wb = Workbook()
ws = wb.active 
ws.title = "무신사 리뷰"
ws.append(["상품명","리뷰"])

for r in all_reviews : 
    ws.append([r["상품명"],r["리뷰"]])

wb.save("musinsa_top30_review.xlsx")
print("저장완료")
# Out:
# 1번째 상품리뷰 수집 중 : {'Retro Motorcycle Graphic Tee White'}
# 2번째 상품리뷰 수집 중 : {'UNICORN CROP TEE BK'}
# 3번째 상품리뷰 수집 중 : {'오버핏 크루넥 메탈릭 크롬 하트 로고 반팔 티셔츠 블랙'}
# 4번째 상품리뷰 수집 중 : {'Identity T Shirt - Blue'}
# 5번째 상품리뷰 수집 중 : {'460G 다트 헤비 머드 다잉 티셔츠-더스키 버건디-'}
# 6번째 상품리뷰 수집 중 : {'[4color] Daily Supima Logo Half T'}
# 7번째 상품리뷰 수집 중 : {'[3PACK] 테크니컬 쿨링 티셔츠'}
# 8번째 상품리뷰 수집 중 : {'럭비 카라 래글런 트랙 타슬란 반팔티 GT-377'}
# 9번째 상품리뷰 수집 중 : {'HUH!! TEE [WHITE]'}
# 10번째 상품리뷰 수집 중 : {'Heart Patch Cotton T-shirt White'}
# 11번째 상품리뷰 수집 중 : {'세미크롭 링거 파리 반팔 티셔츠 GT-357'}
# 12번째 상품리뷰 수집 중 : {'OHP X MOAI b캠핑 세미오버 반팔티'}
# 13번째 상품리뷰 수집 중 : {'2PACK COOL TEE_WHITE(IK2DMMT505A)'}
# 14번째 상품리뷰 수집 중 : {'[PAT&MAT] 베스트 프렌드 티셔츠 - 화이트'}
# 15번째 상품리뷰 수집 중 : {'WOMEN 크롭 플리츠 비엔나 플레어 반팔티 [BLACK]'}
# 16번째 상품리뷰 수집 중 : {'[쿨탠다드] 우먼즈 짐 액티브 숏 슬리브 (2color)'}
# 17번째 상품리뷰 수집 중 : {'백 포인트 스튜디오 오버핏 반팔 티_5COLOR'}
# 18번째 상품리뷰 수집 중 : {'ODSD 스트라이프 레귤러핏 티셔츠 - IVORY'}
# 19번째 상품리뷰 수집 중 : {'Love Leopard Graphic T-shirt VW5ME607_3color'}
# 20번째 상품리뷰 수집 중 : {'[반팔ver]나그랑뒷반팔티셔츠(PBE03S-WHTW004)'}
# 21번째 상품리뷰 수집 중 : {'심볼 로고 피그먼트 티셔츠-4Color'}
# 리뷰 수집 실패 Message: element not interactable
#   (Session info: chrome=138.0.7204.184); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#elementnotinteractableexception
# Stacktrace:
# 	GetHandleVerifier [0x0xc9ba83+63395]
# 	GetHandleVerifier [0x0xc9bac4+63460]
# 	(No symbol) [0x0xae1f70]
# 	(No symbol) [0x0xb2b9f4]
# 	(No symbol) [0x0xb20515]
# 	(No symbol) [0x0xb4f3ac]
# 	(No symbol) [0x0xb1ffa4]
# 	(No symbol) [0x0xb4f624]
# 	(No symbol) [0x0xb707ba]
# 	(No symbol) [0x0xb4f1a6]
# 	(No symbol) [0x0xb1e7b2]
# 	(No symbol) [0x0xb1f654]
# 	GetHandleVerifier [0x0xf18883+2672035]
# 	GetHandleVerifier [0x0xf13cba+2652634]
# 	GetHandleVerifier [0x0xcc2bca+223466]
# 	GetHandleVerifier [0x0xcb2cb8+158168]
# 	GetHandleVerifier [0x0xcb978d+185517]
# 	GetHandleVerifier [0x0xca3b78+96408]
# 	GetHandleVerifier [0x0xca3d02+96802]
# 	GetHandleVerifier [0x0xc8e90a+9770]
# 	BaseThreadInitThunk [0x0x7526fcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f582ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f5827e+238]
#
# 22번째 상품리뷰 수집 중 : {'WEB LOGO T-SHIRTS [WHITE/CAMO]'}
# 23번째 상품리뷰 수집 중 : {'Starlight T-shirts Brown'}
# 24번째 상품리뷰 수집 중 : {'가먼트 다잉 숏 슬리브 [차콜]'}
# 25번째 상품리뷰 수집 중 : {'VSW Cartoon 2 T-Shirts White'}
# 26번째 상품리뷰 수집 중 : {'98 캘리포니아 래글런 반팔 티셔츠-크림'}
# 27번째 상품리뷰 수집 중 : {'에센셜 베이직 이너티셔츠 3팩 (WH2/BK)'}
# 28번째 상품리뷰 수집 중 : {'시그니처 오버핏 반팔티 2colors'}
# 29번째 상품리뷰 수집 중 : {'[Mmlg] STAMP COLLECTOR HF-T (ASH GREY)'}
# 30번째 상품리뷰 수집 중 : {'시트론 썸머 그래픽 반팔 티셔츠 세터데이 화이트'}
# 저장완료

# %%
pip install sqlalchemy
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: sqlalchemy in c:\programdata\anaconda3\lib\site-packages (2.0.39)
# Requirement already satisfied: greenlet!=0.4.17 in c:\programdata\anaconda3\lib\site-packages (from sqlalchemy) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.6.0 in c:\users\user\appdata\roaming\python\python313\site-packages (from sqlalchemy) (4.14.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pymysql 
import pandas as pd 
from sqlalchemy import create_engine

EXCEL_PATH = "musinsa_top30_review.xlsx"
DB_NAME = "musinsa_db"
TABLE_NAME = "reviews"
USER = "root"
PASSWORD = "hithere4961"
HOST = "127.0.0.1"
PORT = 3306

df = pd.read_excel(EXCEL_PATH)

conn = pymysql.connect(host=HOST,user=USER,password=PASSWORD,port=PORT)
cursor = conn.cursor()
cursor.execute(
    f"CREATE DATABASE IF NOT EXISTS {DB_NAME} CHARACTER SET utf8mb4 COLLATE utf8mb4_unicode_ci;"
    
)

conn.close()

engine_str = f"mysql+pymysql://{USER}:{PASSWORD}@{HOST}:{PORT}/{DB_NAME}?charset=utf8mb4"
engine = create_engine(engine_str)

df.to_sql(name=TABLE_NAME, con=engine, if_exists="replace", index=False)


print(f"완료")
# Out:
# 완료
