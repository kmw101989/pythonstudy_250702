# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time  

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service = service, options=options)

url = "https://www.instagram.com/accounts/login/"
driver.get(url)
print("수동 인증 시작")
time.sleep(30)

with open("instagram_cookies.pkl","wb") as f : 
    pickle.dump(driver.get_cookies(),f)
print("쿠키 저장 완료")
driver.quit()
# Out:
# 수동 인증 시작
# 쿠키 저장 완료

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time  

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service = service, options=options)
url = "https://www.instagram.com/accounts/login/"
driver.get(url)
with open("instagram_cookies.pkl","rb") as f :
    cookies = pickle.load(f)
for cookie in cookies : 
    driver.add_cookie(cookie)

driver.refresh()
time.sleep(3)

try: 
    not_now = driver.find_element(By.XPATH, "//button[text()='나중에 하기']")
    not_now.click()
    time.sleep(2)

except: 
    pass

keyword = "무신사"
driver.get(f"https://www.instagram.com/explore/tags/{keyword}")
time.sleep(3)

post_links = set() 
for i in range(3) : 
    links = driver.find_elements(By.TAG_NAME , "a")
    for link in links : 
        href = link.get_attribute("href")
        if href and "/p/" in href : 
            post_links.add(href)
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(3)

results = []
for url in list(post_links) [:10]:
    driver.get(url)
    time.sleep(2)
    caption = ""

    try: 
        img_tag = driver.find_element(By.XPATH, "//img[@alt]")
        caption = img_tag.get_attribute("alt").strip()
        results.append({"url":url, "caption" : caption, "text":text})
    except Exception as e : 
        print(f"캡션 추출 실패:{url} | {e}")
        continue

driver.quit()

for r in results : 
    print(r["url"])
    print(r["caption"])
    print("="*60)
# Out:
# https://www.instagram.com/p/DIgHAdGSgLr/
# Photo by 민수픽 on April 16, 2025. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DJ3bwxbhmzR/
# Photo shared by 장예원 on May 19, 2025 tagging @musinsa.official. 사람 1명 이상, 머리카락 및 타이츠의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMIeAU0p4Q0/
# Photo by 유굴이 on July 15, 2025. 사람 2명, 머리카락, 더플코트, 상의, 파카 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DIbHP3ZyHtp/
# Photo by MUSINSA 무신사 on April 14, 2025. 사진 설명이 없습니다..
# ============================================================
# https://www.instagram.com/p/DKxAxhyhmPe/
# Photo shared by 세마리 on June 11, 2025 tagging @musinsa.official, and @ocelot__kids. 사람 1명, 단발의 앞머리, 공부하는 사람, 반바지 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DJOvHQUpxWx/
# Photo shared by @se_siumii on May 04, 2025 tagging @calvinklein, @bohemian_seoul, @ohwoahcoffee, @threetimess, and @doffsept_official. 사람 1명 이상, 머리카락, 목에 꼭 끼는 목걸이, 상의 및 그물코 스타킹의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMj7y8FOk3C/
# Photo shared by &tailor. l 나에게 맞는 tone-up on July 25, 2025 tagging @sonxungchan, and @tailor.et. 사람 1명 및 문구: '@sonxungchan &tailor. LEA 야외 테라스에서 커피 마시는 느좋남'의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DLyrlpBzx9S/
# Photo shared by 우희성 on July 06, 2025 tagging @allclassic_official. 사람 1명, 윙팁 신발, 담배 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DLAT_tcyCAK/
# Photo by Dear ma ♥ on June 17, 2025. 사람 3명, 책 및 텍스트의 이미지일 수 있음.
# ============================================================
# https://www.instagram.com/p/DMcwWGLTzGn/
# Photo shared by AOKI on July 23, 2025 tagging @zizemuseum. 사람 1명, 머리카락, 슬립, 상의, 스커트, 미니스커트, 반바지, 거울 및 텍스트의 이미지일 수 있음.
# ============================================================
