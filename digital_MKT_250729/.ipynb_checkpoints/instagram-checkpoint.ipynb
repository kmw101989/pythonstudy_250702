# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time  

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service = service, options=options)

url = "https://www.instagram.com/accounts/login/"
driver.get(url)
print("수동 인증 시작")
time.sleep(30)

with open("instagram_cookies.pkl","wb") as f : 
    pickle.dump(driver.get_cookies(),f)
print("쿠키 저장 완료")
driver.quit()
# Out:
# 수동 인증 시작
# 쿠키 저장 완료

# %%
from selenium import webdriver
from selenium.webdriver.chrome.service import Service
from selenium.webdriver.chrome.options import Options
from selenium.webdriver.common.by import By
from webdriver_manager.chrome import ChromeDriverManager
import pickle
import time  

options = Options()
options.add_argument("--start-maximized")
options.add_argument("window-size=1920x1080")
options.add_argument("lang=ko_KR")

service = Service(ChromeDriverManager().install())

driver = webdriver.Chrome(service = service, options=options)
url = "https://www.instagram.com/accounts/login/"
driver.get(url)
with open("instagram_cookies.pkl","rb") as f :
    cookies = pickle.load(f)
for cookie in cookies : 
    driver.add_cookie(cookie)

driver.refresh()
time.sleep(3)

try: 
    not_now = driver.find_element(By.XPATH, "//button[text()='나중에 하기']")
    not_now.click()
    time.sleep(2)

except: 
    pass

keyword = "무신사"
driver.get(f"https://www.instagram.com/explore/tags/{keyword}")
time.sleep(3)

post_links = set() 
for i in range(3) : 
    links = driver.find_elements(By.TAG_NAME , "a")
    for link in links : 
        href = link.get_attribute("href")
        if href and "/p/" in href : 
            post_links.add(href)
    driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")
    time.sleep(3)

results = []
for url in list(post_links) [:10]:
    driver.get(url)
    time.sleep(2)
    caption = ""

    try: 
        img_tag = driver.find_element(By.XPATH, "//img[@alt]")
        caption = img_tag.get_attribute("alt").strip()
         
        results.append({"url":url, "caption" : caption, "text":text})
    except Exception as e : 
        print(f"캡션 추출 실패:{url} | {e}")
        continue

driver.quit()

for r in results : 
    print(r["url"])
   
    print(r["caption"])
    print("="*60)
# Out:
# 캡션 추출 실패:https://www.instagram.com/p/DLHF66wR0U7/ | Message: no such element: Unable to locate element: {"method":"css selector","selector":"#mount_0_0_eO > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.html-div.xdj266r.x14z9mp.xat24cr.x1lziwak.xexx8yu.xyri2b.x18d9i69.x1c1uobl.x9f619.x1f5funs.xvbhtw8.x78zum5.x15mokao.x1ga7v0g.x16uus16.xbiv7yw.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.xvc5jky.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x78zum5.xdt5ytf.x11lt19s.x1n2onr6.xph46j.x7x3xai.xsybdxg.x194l6zq > div > div:nth-child(1) > div:nth-child(1) > div > a > div._aagu > div._aagv > img"}
#   (Session info: chrome=138.0.7204.169); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0xf01af3+62339]
# 	GetHandleVerifier [0x0xf01b34+62404]
# 	(No symbol) [0x0xd42123]
# 	(No symbol) [0x0xd8a86e]
# 	(No symbol) [0x0xd8ac0b]
# 	(No symbol) [0x0xdd2f72]
# 	(No symbol) [0x0xdaf404]
# 	(No symbol) [0x0xdd07a3]
# 	(No symbol) [0x0xdaf1b6]
# 	(No symbol) [0x0xd7e7a2]
# 	(No symbol) [0x0xd7f644]
# 	GetHandleVerifier [0x0x1176683+2637587]
# 	GetHandleVerifier [0x0x1171a8a+2618138]
# 	GetHandleVerifier [0x0xf2856a+220666]
# 	GetHandleVerifier [0x0xf18998+156200]
# 	GetHandleVerifier [0x0xf1f12d+182717]
# 	GetHandleVerifier [0x0xf09a38+94920]
# 	GetHandleVerifier [0x0xf09bc2+95314]
# 	GetHandleVerifier [0x0xef4d0a+9626]
# 	BaseThreadInitThunk [0x0x7526fcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f582ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f5827e+238]
#
# 캡션 추출 실패:https://www.instagram.com/p/DMqORWETaAG/ | Message: no such element: Unable to locate element: {"method":"css selector","selector":"#mount_0_0_eO > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.html-div.xdj266r.x14z9mp.xat24cr.x1lziwak.xexx8yu.xyri2b.x18d9i69.x1c1uobl.x9f619.x1f5funs.xvbhtw8.x78zum5.x15mokao.x1ga7v0g.x16uus16.xbiv7yw.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.xvc5jky.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x78zum5.xdt5ytf.x11lt19s.x1n2onr6.xph46j.x7x3xai.xsybdxg.x194l6zq > div > div:nth-child(1) > div:nth-child(1) > div > a > div._aagu > div._aagv > img"}
#   (Session info: chrome=138.0.7204.169); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0xf01af3+62339]
# 	GetHandleVerifier [0x0xf01b34+62404]
# 	(No symbol) [0x0xd42123]
# 	(No symbol) [0x0xd8a86e]
# 	(No symbol) [0x0xd8ac0b]
# 	(No symbol) [0x0xdd2f72]
# 	(No symbol) [0x0xdaf404]
# 	(No symbol) [0x0xdd07a3]
# 	(No symbol) [0x0xdaf1b6]
# 	(No symbol) [0x0xd7e7a2]
# 	(No symbol) [0x0xd7f644]
# 	GetHandleVerifier [0x0x1176683+2637587]
# 	GetHandleVerifier [0x0x1171a8a+2618138]
# 	GetHandleVerifier [0x0xf2856a+220666]
# 	GetHandleVerifier [0x0xf18998+156200]
# 	GetHandleVerifier [0x0xf1f12d+182717]
# 	GetHandleVerifier [0x0xf09a38+94920]
# 	GetHandleVerifier [0x0xf09bc2+95314]
# 	GetHandleVerifier [0x0xef4d0a+9626]
# 	BaseThreadInitThunk [0x0x7526fcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f582ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f5827e+238]
#
# 캡션 추출 실패:https://www.instagram.com/p/DIgHAdGSgLr/ | Message: no such element: Unable to locate element: {"method":"css selector","selector":"#mount_0_0_eO > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.html-div.xdj266r.x14z9mp.xat24cr.x1lziwak.xexx8yu.xyri2b.x18d9i69.x1c1uobl.x9f619.x1f5funs.xvbhtw8.x78zum5.x15mokao.x1ga7v0g.x16uus16.xbiv7yw.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.xvc5jky.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x78zum5.xdt5ytf.x11lt19s.x1n2onr6.xph46j.x7x3xai.xsybdxg.x194l6zq > div > div:nth-child(1) > div:nth-child(1) > div > a > div._aagu > div._aagv > img"}
#   (Session info: chrome=138.0.7204.169); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0xf01af3+62339]
# 	GetHandleVerifier [0x0xf01b34+62404]
# 	(No symbol) [0x0xd42123]
# 	(No symbol) [0x0xd8a86e]
# 	(No symbol) [0x0xd8ac0b]
# 	(No symbol) [0x0xdd2f72]
# 	(No symbol) [0x0xdaf404]
# 	(No symbol) [0x0xdd07a3]
# 	(No symbol) [0x0xdaf1b6]
# 	(No symbol) [0x0xd7e7a2]
# 	(No symbol) [0x0xd7f644]
# 	GetHandleVerifier [0x0x1176683+2637587]
# 	GetHandleVerifier [0x0x1171a8a+2618138]
# 	GetHandleVerifier [0x0xf2856a+220666]
# 	GetHandleVerifier [0x0xf18998+156200]
# 	GetHandleVerifier [0x0xf1f12d+182717]
# 	GetHandleVerifier [0x0xf09a38+94920]
# 	GetHandleVerifier [0x0xf09bc2+95314]
# 	GetHandleVerifier [0x0xef4d0a+9626]
# 	BaseThreadInitThunk [0x0x7526fcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f582ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f5827e+238]
#
# 캡션 추출 실패:https://www.instagram.com/p/DMIeAU0p4Q0/ | Message: no such element: Unable to locate element: {"method":"css selector","selector":"#mount_0_0_eO > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.html-div.xdj266r.x14z9mp.xat24cr.x1lziwak.xexx8yu.xyri2b.x18d9i69.x1c1uobl.x9f619.x1f5funs.xvbhtw8.x78zum5.x15mokao.x1ga7v0g.x16uus16.xbiv7yw.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.xvc5jky.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x78zum5.xdt5ytf.x11lt19s.x1n2onr6.xph46j.x7x3xai.xsybdxg.x194l6zq > div > div:nth-child(1) > div:nth-child(1) > div > a > div._aagu > div._aagv > img"}
#   (Session info: chrome=138.0.7204.169); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0xf01af3+62339]
# 	GetHandleVerifier [0x0xf01b34+62404]
# 	(No symbol) [0x0xd42123]
# 	(No symbol) [0x0xd8a86e]
# 	(No symbol) [0x0xd8ac0b]
# 	(No symbol) [0x0xdd2f72]
# 	(No symbol) [0x0xdaf404]
# 	(No symbol) [0x0xdd07a3]
# 	(No symbol) [0x0xdaf1b6]
# 	(No symbol) [0x0xd7e7a2]
# 	(No symbol) [0x0xd7f644]
# 	GetHandleVerifier [0x0x1176683+2637587]
# 	GetHandleVerifier [0x0x1171a8a+2618138]
# 	GetHandleVerifier [0x0xf2856a+220666]
# 	GetHandleVerifier [0x0xf18998+156200]
# 	GetHandleVerifier [0x0xf1f12d+182717]
# 	GetHandleVerifier [0x0xf09a38+94920]
# 	GetHandleVerifier [0x0xf09bc2+95314]
# 	GetHandleVerifier [0x0xef4d0a+9626]
# 	BaseThreadInitThunk [0x0x7526fcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f582ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f5827e+238]
#
# 캡션 추출 실패:https://www.instagram.com/p/DJ3bwxbhmzR/ | Message: no such element: Unable to locate element: {"method":"css selector","selector":"#mount_0_0_eO > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.html-div.xdj266r.x14z9mp.xat24cr.x1lziwak.xexx8yu.xyri2b.x18d9i69.x1c1uobl.x9f619.x1f5funs.xvbhtw8.x78zum5.x15mokao.x1ga7v0g.x16uus16.xbiv7yw.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.xvc5jky.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x78zum5.xdt5ytf.x11lt19s.x1n2onr6.xph46j.x7x3xai.xsybdxg.x194l6zq > div > div:nth-child(1) > div:nth-child(1) > div > a > div._aagu > div._aagv > img"}
#   (Session info: chrome=138.0.7204.169); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0xf01af3+62339]
# 	GetHandleVerifier [0x0xf01b34+62404]
# 	(No symbol) [0x0xd42123]
# 	(No symbol) [0x0xd8a86e]
# 	(No symbol) [0x0xd8ac0b]
# 	(No symbol) [0x0xdd2f72]
# 	(No symbol) [0x0xdaf404]
# 	(No symbol) [0x0xdd07a3]
# 	(No symbol) [0x0xdaf1b6]
# 	(No symbol) [0x0xd7e7a2]
# 	(No symbol) [0x0xd7f644]
# 	GetHandleVerifier [0x0x1176683+2637587]
# 	GetHandleVerifier [0x0x1171a8a+2618138]
# 	GetHandleVerifier [0x0xf2856a+220666]
# 	GetHandleVerifier [0x0xf18998+156200]
# 	GetHandleVerifier [0x0xf1f12d+182717]
# 	GetHandleVerifier [0x0xf09a38+94920]
# 	GetHandleVerifier [0x0xf09bc2+95314]
# 	GetHandleVerifier [0x0xef4d0a+9626]
# 	BaseThreadInitThunk [0x0x7526fcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f582ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f5827e+238]
#
# 캡션 추출 실패:https://www.instagram.com/p/DKxAxhyhmPe/ | Message: no such element: Unable to locate element: {"method":"css selector","selector":"#mount_0_0_eO > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.html-div.xdj266r.x14z9mp.xat24cr.x1lziwak.xexx8yu.xyri2b.x18d9i69.x1c1uobl.x9f619.x1f5funs.xvbhtw8.x78zum5.x15mokao.x1ga7v0g.x16uus16.xbiv7yw.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.xvc5jky.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x78zum5.xdt5ytf.x11lt19s.x1n2onr6.xph46j.x7x3xai.xsybdxg.x194l6zq > div > div:nth-child(1) > div:nth-child(1) > div > a > div._aagu > div._aagv > img"}
#   (Session info: chrome=138.0.7204.169); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0xf01af3+62339]
# 	GetHandleVerifier [0x0xf01b34+62404]
# 	(No symbol) [0x0xd42123]
# 	(No symbol) [0x0xd8a86e]
# 	(No symbol) [0x0xd8ac0b]
# 	(No symbol) [0x0xdd2f72]
# 	(No symbol) [0x0xdaf404]
# 	(No symbol) [0x0xdd07a3]
# 	(No symbol) [0x0xdaf1b6]
# 	(No symbol) [0x0xd7e7a2]
# 	(No symbol) [0x0xd7f644]
# 	GetHandleVerifier [0x0x1176683+2637587]
# 	GetHandleVerifier [0x0x1171a8a+2618138]
# 	GetHandleVerifier [0x0xf2856a+220666]
# 	GetHandleVerifier [0x0xf18998+156200]
# 	GetHandleVerifier [0x0xf1f12d+182717]
# 	GetHandleVerifier [0x0xf09a38+94920]
# 	GetHandleVerifier [0x0xf09bc2+95314]
# 	GetHandleVerifier [0x0xef4d0a+9626]
# 	BaseThreadInitThunk [0x0x7526fcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f582ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f5827e+238]
#
# 캡션 추출 실패:https://www.instagram.com/p/DJOvHQUpxWx/ | Message: no such element: Unable to locate element: {"method":"css selector","selector":"#mount_0_0_eO > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.html-div.xdj266r.x14z9mp.xat24cr.x1lziwak.xexx8yu.xyri2b.x18d9i69.x1c1uobl.x9f619.x1f5funs.xvbhtw8.x78zum5.x15mokao.x1ga7v0g.x16uus16.xbiv7yw.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.xvc5jky.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x78zum5.xdt5ytf.x11lt19s.x1n2onr6.xph46j.x7x3xai.xsybdxg.x194l6zq > div > div:nth-child(1) > div:nth-child(1) > div > a > div._aagu > div._aagv > img"}
#   (Session info: chrome=138.0.7204.169); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0xf01af3+62339]
# 	GetHandleVerifier [0x0xf01b34+62404]
# 	(No symbol) [0x0xd42123]
# 	(No symbol) [0x0xd8a86e]
# 	(No symbol) [0x0xd8ac0b]
# 	(No symbol) [0x0xdd2f72]
# 	(No symbol) [0x0xdaf404]
# 	(No symbol) [0x0xdd07a3]
# 	(No symbol) [0x0xdaf1b6]
# 	(No symbol) [0x0xd7e7a2]
# 	(No symbol) [0x0xd7f644]
# 	GetHandleVerifier [0x0x1176683+2637587]
# 	GetHandleVerifier [0x0x1171a8a+2618138]
# 	GetHandleVerifier [0x0xf2856a+220666]
# 	GetHandleVerifier [0x0xf18998+156200]
# 	GetHandleVerifier [0x0xf1f12d+182717]
# 	GetHandleVerifier [0x0xf09a38+94920]
# 	GetHandleVerifier [0x0xf09bc2+95314]
# 	GetHandleVerifier [0x0xef4d0a+9626]
# 	BaseThreadInitThunk [0x0x7526fcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f582ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f5827e+238]
#
# 캡션 추출 실패:https://www.instagram.com/p/DMj7y8FOk3C/ | Message: no such element: Unable to locate element: {"method":"css selector","selector":"#mount_0_0_eO > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.html-div.xdj266r.x14z9mp.xat24cr.x1lziwak.xexx8yu.xyri2b.x18d9i69.x1c1uobl.x9f619.x1f5funs.xvbhtw8.x78zum5.x15mokao.x1ga7v0g.x16uus16.xbiv7yw.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.xvc5jky.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x78zum5.xdt5ytf.x11lt19s.x1n2onr6.xph46j.x7x3xai.xsybdxg.x194l6zq > div > div:nth-child(1) > div:nth-child(1) > div > a > div._aagu > div._aagv > img"}
#   (Session info: chrome=138.0.7204.169); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0xf01af3+62339]
# 	GetHandleVerifier [0x0xf01b34+62404]
# 	(No symbol) [0x0xd42123]
# 	(No symbol) [0x0xd8a86e]
# 	(No symbol) [0x0xd8ac0b]
# 	(No symbol) [0x0xdd2f72]
# 	(No symbol) [0x0xdaf404]
# 	(No symbol) [0x0xdd07a3]
# 	(No symbol) [0x0xdaf1b6]
# 	(No symbol) [0x0xd7e7a2]
# 	(No symbol) [0x0xd7f644]
# 	GetHandleVerifier [0x0x1176683+2637587]
# 	GetHandleVerifier [0x0x1171a8a+2618138]
# 	GetHandleVerifier [0x0xf2856a+220666]
# 	GetHandleVerifier [0x0xf18998+156200]
# 	GetHandleVerifier [0x0xf1f12d+182717]
# 	GetHandleVerifier [0x0xf09a38+94920]
# 	GetHandleVerifier [0x0xf09bc2+95314]
# 	GetHandleVerifier [0x0xef4d0a+9626]
# 	BaseThreadInitThunk [0x0x7526fcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f582ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f5827e+238]
#
# 캡션 추출 실패:https://www.instagram.com/p/DLyrlpBzx9S/ | Message: no such element: Unable to locate element: {"method":"css selector","selector":"#mount_0_0_eO > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.html-div.xdj266r.x14z9mp.xat24cr.x1lziwak.xexx8yu.xyri2b.x18d9i69.x1c1uobl.x9f619.x1f5funs.xvbhtw8.x78zum5.x15mokao.x1ga7v0g.x16uus16.xbiv7yw.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.xvc5jky.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x78zum5.xdt5ytf.x11lt19s.x1n2onr6.xph46j.x7x3xai.xsybdxg.x194l6zq > div > div:nth-child(1) > div:nth-child(1) > div > a > div._aagu > div._aagv > img"}
#   (Session info: chrome=138.0.7204.169); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0xf01af3+62339]
# 	GetHandleVerifier [0x0xf01b34+62404]
# 	(No symbol) [0x0xd42123]
# 	(No symbol) [0x0xd8a86e]
# 	(No symbol) [0x0xd8ac0b]
# 	(No symbol) [0x0xdd2f72]
# 	(No symbol) [0x0xdaf404]
# 	(No symbol) [0x0xdd07a3]
# 	(No symbol) [0x0xdaf1b6]
# 	(No symbol) [0x0xd7e7a2]
# 	(No symbol) [0x0xd7f644]
# 	GetHandleVerifier [0x0x1176683+2637587]
# 	GetHandleVerifier [0x0x1171a8a+2618138]
# 	GetHandleVerifier [0x0xf2856a+220666]
# 	GetHandleVerifier [0x0xf18998+156200]
# 	GetHandleVerifier [0x0xf1f12d+182717]
# 	GetHandleVerifier [0x0xf09a38+94920]
# 	GetHandleVerifier [0x0xf09bc2+95314]
# 	GetHandleVerifier [0x0xef4d0a+9626]
# 	BaseThreadInitThunk [0x0x7526fcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f582ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f5827e+238]
#
# 캡션 추출 실패:https://www.instagram.com/p/DLAT_tcyCAK/ | Message: no such element: Unable to locate element: {"method":"css selector","selector":"#mount_0_0_eO > div > div > div.x9f619.x1n2onr6.x1ja2u2z > div > div > div.x78zum5.xdt5ytf.x1t2pt76.x1n2onr6.x1ja2u2z.x10cihs4 > div.html-div.xdj266r.x14z9mp.xat24cr.x1lziwak.xexx8yu.xyri2b.x18d9i69.x1c1uobl.x9f619.x1f5funs.xvbhtw8.x78zum5.x15mokao.x1ga7v0g.x16uus16.xbiv7yw.x1uhb9sk.x1plvlek.xryxfnj.x1c4vz4f.x2lah0s.x1q0g3np.xqjyukv.x1qjc9v5.x1oa3qoh.x1qughib > div.xvc5jky.xh8yej3.x10o80wk.x14k21rp.x17snn68.x6osk4m.x1porb0y.x8vgawa > section > main > div > div.x78zum5.xdt5ytf.x11lt19s.x1n2onr6.xph46j.x7x3xai.xsybdxg.x194l6zq > div > div:nth-child(1) > div:nth-child(1) > div > a > div._aagu > div._aagv > img"}
#   (Session info: chrome=138.0.7204.169); For documentation on this error, please visit: https://www.selenium.dev/documentation/webdriver/troubleshooting/errors#nosuchelementexception
# Stacktrace:
# 	GetHandleVerifier [0x0xf01af3+62339]
# 	GetHandleVerifier [0x0xf01b34+62404]
# 	(No symbol) [0x0xd42123]
# 	(No symbol) [0x0xd8a86e]
# 	(No symbol) [0x0xd8ac0b]
# 	(No symbol) [0x0xdd2f72]
# 	(No symbol) [0x0xdaf404]
# 	(No symbol) [0x0xdd07a3]
# 	(No symbol) [0x0xdaf1b6]
# 	(No symbol) [0x0xd7e7a2]
# 	(No symbol) [0x0xd7f644]
# 	GetHandleVerifier [0x0x1176683+2637587]
# 	GetHandleVerifier [0x0x1171a8a+2618138]
# 	GetHandleVerifier [0x0xf2856a+220666]
# 	GetHandleVerifier [0x0xf18998+156200]
# 	GetHandleVerifier [0x0xf1f12d+182717]
# 	GetHandleVerifier [0x0xf09a38+94920]
# 	GetHandleVerifier [0x0xf09bc2+95314]
# 	GetHandleVerifier [0x0xef4d0a+9626]
# 	BaseThreadInitThunk [0x0x7526fcc9+25]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f582ae+286]
# 	RtlGetAppContainerNamedObjectPath [0x0x76f5827e+238]
