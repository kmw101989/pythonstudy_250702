# %%
import requests
import mysql.connector
from datetime import datetime
from zoneinfo import ZoneInfo
SUPABASE_URL = "https://iixerpusrzbqsgrcybqv.supabase.co"
SUPABASE_ANON_KEY = "eyJhbGciOiJIUzI1NiIsInR5cCI6IkpXVCJ9.eyJpc3MiOiJzdXBhYmFzZSIsInJlZiI6ImlpeGVycHVzcnpicXNncmN5YnF2Iiwicm9sZSI6ImFub24iLCJpYXQiOjE3NjUzMzU1ODIsImV4cCI6MjA4MDkxMTU4Mn0.C_Z6JeMJmLnoscNrHGcNkK-lwXC_7zwY3f2kitxcjFk"
SUPABASE_TABLE = "comments"
SUPABASE_API = f"{SUPABASE_URL}/rest/v1/{SUPABASE_TABLE}"
headers = {
    "apikey": SUPABASE_ANON_KEY,
    "Authorization": f"Bearer {SUPABASE_ANON_KEY}"
}
params = {
    "select": "*",
    "order": "id.asc",
    "limit": 1000
}
resp = requests.get(SUPABASE_API, headers=headers, params=params)
resp.raise_for_status()
rows = resp.json()
MYSQL_CONFIG = {
    "host": "127.0.0.1",
    "user": "root",
    "password": "hithere4961",
    "database": "finaltest"
}
# conn = mysql.connector.connect(host="127.0.0.1", user="root", )
conn = mysql.connector.connect(**MYSQL_CONFIG) #unpacking
cur = conn.cursor()
create_table_sql = """
CREATE TABLE IF NOT EXISTS comments (
    id BIGINT PRIMARY KEY,
    book_url TEXT NOT NULL,
    nickname VARCHAR(100) NOT NULL,
    comment_text TEXT NOT NULL,
    created_at DATETIME
);
"""
cur.execute(create_table_sql)
insert_sql = """
INSERT INTO comments (id, book_url, nickname, comment_text, created_at)
VALUES (%s, %s, %s, %s, %s)
ON DUPLICATE KEY UPDATE
    id = VALUES(id),
    book_url = VALUES(book_url),
    nickname = VALUES(nickname),
    comment_text = VALUES(comment_text),
    created_at = VALUES(created_at);
"""
def to_kst(utc_str) :
    if not utc_str :
        return None
    utc_dt = datetime.fromisoformat(utc_str.replace("Z", "+00:00"))
    kst_dt = utc_dt.astimezone(ZoneInfo("Asia/Seoul"))
    return kst_dt.strftime("%Y-%m-%d %H:%M:%S")
data_to_insert = []
for r in rows :
    data_to_insert.append((
        r.get("id"),
        r.get("book_url"),
        r.get("nickname"),
        r.get("comment_text"),
        to_kst(r.get("created_at")),
    ))
cur.executemany(insert_sql, data_to_insert)
conn.commit()
print(f"MySQL에 정상적으로 데이터를 삽입/업데이트 했습니다.")
cur.close()
conn.close()
# Out:
# MySQL에 정상적으로 데이터를 삽입/업데이트 했습니다.

# %%
from wordcloud import WordCloud

import matplotlib.pyplot as plt 

text = " ".join(words) 
wc = WordCloud(
    font_path = "/Library/Fonts/AppleGothic.ttf", 
    background_color = "white",
    width = 800,
    height = 400
).generate(text)

plt.figure(figsize=(12,6))
plt.imshow(wc,interpolation="bilinear")
plt.axis("off") 
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[5], line 5
#       1 from wordcloud import WordCloud
#       3 import matplotlib.pyplot as plt
# ----> 5 text = " ".join(words)
#       6 wc = WordCloud(
#       7     font_path = "/Library/Fonts/AppleGothic.ttf",
#       8     background_color = "white",
#       9     width = 800,
#      10     height = 400
#      11 ).generate(text)
#      13 plt.figure(figsize=(12,6))
#
# NameError: name 'words' is not defined

# %%
pip install wordcloud
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip
